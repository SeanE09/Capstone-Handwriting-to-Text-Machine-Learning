# %%
conda activate TFgpu

# %% [markdown]
# <div align="center">
#   <img src="DisplayIMG/Cartoon.png" alt="Image Description" />
# </div>

# %%
# import cv2
# import os
# import numpy as np
# from PIL import Image
# import pandas as pd
# from sklearn import preprocessing
# from sklearn.model_selection import train_test_split
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
# from tensorflow.keras.callbacks import EarlyStopping
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.optimizers import SGD
# import glob
# from tensorflow.keras.callbacks import ModelCheckpoint
# from sklearn.metrics import classification_report

# # Get the current directory
# current_directory = os.getcwd()

# # Specify the folder name where the images are located
# folder_name = "img"

# # Construct the folder path
# folder_path = os.path.join(current_directory, folder_name)

# # Specify the CSV file path containing image labels
# csv_file_path = os.path.join(current_directory, "labels", "english-clean.csv")

# # Read the CSV file into a DataFrame
# df = pd.read_csv(csv_file_path)

# # Create a dictionary where keys are filenames and values are labels
# labels_dict = df.set_index('image')['label'].to_dict()

# def load_images_from_folder(folder, labels_dict):
#     images = []
#     labels = []
#     for file_path in glob.glob(os.path.join(folder, "*.png")):
#         img = Image.open(file_path)
#         if img is not None:
#             img = img.convert('L')  # Convert image to grayscale
#             img = img.resize((64, 64))  # Resize the image
#             np_img = np.array(img)
#             images.append(np_img)
#             filename = os.path.basename(file_path)
#             label = labels_dict[filename]  # Get the label from the filename
#             labels.append(label)
#     return images, labels

# images, labels = load_images_from_folder(folder_path, labels_dict)

# le = preprocessing.LabelEncoder()
# numerical_labels = le.fit_transform(labels)  # Convert labels to integers

# images = np.array(images)  # Convert list of arrays to a single array
# images = images / 255.0  # Normalize pixel values
# images = images.reshape(-1, 64, 64, 1)  # Reshape array for CNN

# encoded_labels = to_categorical(numerical_labels)  # One-hot encode labels

# X_train, X_test, y_train, y_test = train_test_split(images, encoded_labels, test_size=0.2, random_state=42, shuffle=True)



# model = Sequential()

# model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 1)))
# model.add(BatchNormalization())
# model.add(Conv2D(32, (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.15))  # Adjusted Dropout

# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(Conv2D(128, (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.3))  # Adjusted Dropout

# model.add(Flatten())

# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))  # Adjusted Dropout

# num_classes = len(set(numerical_labels))
# model.add(Dense(num_classes, activation='softmax'))

# # Changed optimizer to SGD
# opt = SGD(learning_rate=0.01, momentum=0.9)
# model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])


# # Data augmentation
# datagen = ImageDataGenerator(
#     rotation_range=30,
#     zoom_range = 0.05,
#     width_shift_range=0.05,
#     height_shift_range=0.05)

# datagen.fit(X_train)

# # Early stopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=200)


# # Model Checkpoint
# checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)

# # Fit the model
# model.fit(datagen.flow(X_train, y_train, batch_size=32),
#           epochs=1000,
#           validation_data=(X_test, y_test),
#           callbacks=[early_stopping])

# history = model.fit(X_train, y_train)

# # 86/86 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9974
# # Train Loss: 0.013188091106712818
# # Train Accuracy: 0.9974340200424194
    
# # 22/22 [==============================] - 0s 3ms/step - loss: 0.6097 - accuracy: 0.8504
# # Test Loss: 0.6097488403320312
# # Test Accuracy: 0.8504399061203003
# # 22/22 [==============================] - 0s 3ms/step

# # Epoch 1641/10000
# # 86/86 [==============================] - 1s 10ms/step - loss: 0.0711 - accuracy: 0.9721 - val_loss: 0.6484 - val_accuracy: 0.8431
# # 86/86 [==============================] - 1s 11ms/step - loss: 0.0357 - accuracy: 0.9846

# %%
num_cores = os.cpu_count()  # Get number of CPU cores
num_cores_to_use = num_cores // 2  # Use half of the cores

num_cores

# %%
num_cores_to_use

# %%
import cv2
import os
import numpy as np
from PIL import Image
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
import glob
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import math



# Get the current directory
current_directory = os.getcwd()

# Specify the folder name where the images are located
folder_name = "img"

# Construct the folder path
folder_path = os.path.join(current_directory, folder_name)

# Specify the CSV file path containing image labels
csv_file_path = os.path.join(current_directory, "labels", "english-clean.csv")

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Create a dictionary where keys are filenames and values are labels
labels_dict = df.set_index('image')['label'].to_dict()

def load_images_from_folder(folder, labels_dict):
    images = []
    labels = []
    for file_path in glob.glob(os.path.join(folder, "*.png")):
        img = Image.open(file_path)
        if img is not None:
            img = img.convert('L')  # Convert image to grayscale
            img = img.resize((64, 64))  # Resize the image
            np_img = np.array(img)
            images.append(np_img)
            filename = os.path.basename(file_path)
            label = labels_dict[filename]  # Get the label from the filename
            labels.append(label)
    return images, labels

images, labels = load_images_from_folder(folder_path, labels_dict)

le = preprocessing.LabelEncoder()
numerical_labels = le.fit_transform(labels)  # Convert labels to integers

images = np.array(images)  # Convert list of arrays to a single array
images = images / 255.0  # Normalize pixel values
images = images.reshape(-1, 64, 64, 1)  # Reshape array for CNN

encoded_labels = to_categorical(numerical_labels)  # One-hot encode labels

X_train, X_test, y_train, y_test = train_test_split(images, encoded_labels, test_size=0.2, random_state=42, shuffle=True)

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 1)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.1))  # Adjusted Dropout

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.1))  # Adjusted Dropout

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
# model.add(Dropout(0.1)) # Adjusted Dropout
           

num_classes = len(set(numerical_labels))
model.add(Dense(num_classes, activation='softmax'))

# Changed optimizer to SGD
opt = SGD(learning_rate=0.01, momentum=0.9)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range = 0.1, # Increased zoom_range
    width_shift_range=0.1, # Increased shift range
    height_shift_range=0.1, # Increased shift range
    shear_range=0.1,  # Added shear transformation)
    horizontal_flip=False,  # Horizontal flip
    vertical_flip=False  # Vertical flip
)
    
datagen.fit(X_train)

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=100)

# Model Checkpoint
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)

# Fit the model
history = model.fit(datagen.flow(X_train, y_train, batch_size=32),
          epochs=300,
          validation_data=(X_test, y_test)
                    
#           ,callbacks=[early_stopping, checkpoint]
                   )

# Plot training & validation accuracy values
plt.figure(figsize=[6,4])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=[6,4])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(X_test, y_test, batch_size=128)
print("test loss, test accuracy:", results)
# Out:
# Epoch 1/300
# 86/86 [==============================] - 5s 49ms/step - loss: 3.6755 - accuracy: 0.1367 - val_loss: 21.0405 - val_accuracy: 0.0147
# Epoch 2/300
# 86/86 [==============================] - 4s 48ms/step - loss: 2.6417 - accuracy: 0.3277 - val_loss: 15.4825 - val_accuracy: 0.0293
# Epoch 3/300
# 86/86 [==============================] - 4s 49ms/step - loss: 1.9786 - accuracy: 0.4820 - val_loss: 8.3899 - val_accuracy: 0.0557
# Epoch 4/300
# 86/86 [==============================] - 4s 45ms/step - loss: 1.5683 - accuracy: 0.5814 - val_loss: 7.5720 - val_accuracy: 0.0249
# Epoch 5/300
# 86/86 [==============================] - 4s 45ms/step - loss: 1.2785 - accuracy: 0.6433 - val_loss: 7.4625 - val_accuracy: 0.0528
# Epoch 6/300
# 86/86 [==============================] - 4s 46ms/step - loss: 1.0561 - accuracy: 0.6943 - val_loss: 7.3569 - val_accuracy: 0.0792
# Epoch 7/300
# 86/86 [==============================] - 4s 51ms/step - loss: 0.9336 - accuracy: 0.7203 - val_loss: 11.0829 - val_accuracy: 0.0616
# Epoch 8/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.8863 - accuracy: 0.7342 - val_loss: 7.0811 - val_accuracy: 0.1818
# Epoch 9/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.7621 - accuracy: 0.7709 - val_loss: 9.1154 - val_accuracy: 0.1422
# Epoch 10/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.7286 - accuracy: 0.7808 - val_loss: 9.0034 - val_accuracy: 0.1261
# Epoch 11/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.6405 - accuracy: 0.8098 - val_loss: 10.6124 - val_accuracy: 0.1041
# Epoch 12/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.6112 - accuracy: 0.8094 - val_loss: 15.9067 - val_accuracy: 0.0674
# Epoch 13/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.5669 - accuracy: 0.8211 - val_loss: 12.7780 - val_accuracy: 0.0836
# Epoch 14/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.5264 - accuracy: 0.8310 - val_loss: 7.7449 - val_accuracy: 0.1848
# Epoch 15/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.5606 - accuracy: 0.8237 - val_loss: 18.7881 - val_accuracy: 0.0718
# Epoch 16/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.5242 - accuracy: 0.8251 - val_loss: 107.7998 - val_accuracy: 0.0293
# Epoch 17/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.4821 - accuracy: 0.8475 - val_loss: 9.0116 - val_accuracy: 0.1041
# Epoch 18/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.4687 - accuracy: 0.8438 - val_loss: 54.3751 - val_accuracy: 0.0513
# Epoch 19/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.4332 - accuracy: 0.8559 - val_loss: 16.5726 - val_accuracy: 0.0645
# Epoch 20/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.4168 - accuracy: 0.8596 - val_loss: 13.7757 - val_accuracy: 0.0601
# Epoch 21/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.4036 - accuracy: 0.8680 - val_loss: 8.8184 - val_accuracy: 0.1276
# Epoch 22/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.3894 - accuracy: 0.8706 - val_loss: 8.4323 - val_accuracy: 0.1730
# Epoch 23/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.4210 - accuracy: 0.8578 - val_loss: 36.7569 - val_accuracy: 0.0587
# Epoch 24/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.3607 - accuracy: 0.8757 - val_loss: 4.5749 - val_accuracy: 0.3065
# Epoch 25/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.3746 - accuracy: 0.8691 - val_loss: 1.7942 - val_accuracy: 0.6012
# Epoch 26/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.3645 - accuracy: 0.8768 - val_loss: 12.9211 - val_accuracy: 0.1349
# Epoch 27/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.3537 - accuracy: 0.8750 - val_loss: 1.7357 - val_accuracy: 0.6026
# Epoch 28/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.3369 - accuracy: 0.8834 - val_loss: 7.6107 - val_accuracy: 0.2214
# Epoch 29/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.3597 - accuracy: 0.8805 - val_loss: 15.1001 - val_accuracy: 0.0865
# Epoch 30/300
# 86/86 [==============================] - 4s 43ms/step - loss: 0.3241 - accuracy: 0.8904 - val_loss: 10.4943 - val_accuracy: 0.2551
# Epoch 31/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.3181 - accuracy: 0.8867 - val_loss: 69.9866 - val_accuracy: 0.0630
# Epoch 32/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.3062 - accuracy: 0.8941 - val_loss: 29.1592 - val_accuracy: 0.0733
# Epoch 33/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.3112 - accuracy: 0.8856 - val_loss: 13.8888 - val_accuracy: 0.1129
# Epoch 34/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.3102 - accuracy: 0.8886 - val_loss: 38.7346 - val_accuracy: 0.0279
# Epoch 35/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.2820 - accuracy: 0.9036 - val_loss: 16.6872 - val_accuracy: 0.0674
# Epoch 36/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2968 - accuracy: 0.8937 - val_loss: 13.3765 - val_accuracy: 0.4897
# Epoch 37/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.2941 - accuracy: 0.8963 - val_loss: 12.2359 - val_accuracy: 0.1202
# Epoch 38/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.2891 - accuracy: 0.8981 - val_loss: 5.1002 - val_accuracy: 0.6891
# Epoch 39/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.2830 - accuracy: 0.8981 - val_loss: 15.1710 - val_accuracy: 0.0982
# Epoch 40/300
# 86/86 [==============================] - 4s 44ms/step - loss: 0.2671 - accuracy: 0.9007 - val_loss: 3.7454 - val_accuracy: 0.4106
# Epoch 41/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2574 - accuracy: 0.9106 - val_loss: 69.0200 - val_accuracy: 0.0601
# Epoch 42/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.2714 - accuracy: 0.9014 - val_loss: 14.3487 - val_accuracy: 0.1334
# Epoch 43/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.2601 - accuracy: 0.9018 - val_loss: 22.7000 - val_accuracy: 0.1246
# Epoch 44/300
# 86/86 [==============================] - 4s 43ms/step - loss: 0.2709 - accuracy: 0.9043 - val_loss: 10.0162 - val_accuracy: 0.1657
# Epoch 45/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.2651 - accuracy: 0.9032 - val_loss: 20.9753 - val_accuracy: 0.0674
# Epoch 46/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.2650 - accuracy: 0.9040 - val_loss: 16.5587 - val_accuracy: 0.1525
# Epoch 47/300
# 86/86 [==============================] - 5s 57ms/step - loss: 0.2399 - accuracy: 0.9146 - val_loss: 15.2929 - val_accuracy: 0.0924
# Epoch 48/300
# 86/86 [==============================] - 5s 55ms/step - loss: 0.2422 - accuracy: 0.9128 - val_loss: 63.1161 - val_accuracy: 0.0660
# Epoch 49/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2480 - accuracy: 0.9080 - val_loss: 10.6101 - val_accuracy: 0.1584
# Epoch 50/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.2408 - accuracy: 0.9106 - val_loss: 8.9427 - val_accuracy: 0.1730
# Epoch 51/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.2359 - accuracy: 0.9157 - val_loss: 16.5118 - val_accuracy: 0.0587
# Epoch 52/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2505 - accuracy: 0.9095 - val_loss: 13.4126 - val_accuracy: 0.0909
# Epoch 53/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2457 - accuracy: 0.9102 - val_loss: 6.8693 - val_accuracy: 0.2566
# Epoch 54/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.2376 - accuracy: 0.9117 - val_loss: 1.9719 - val_accuracy: 0.6129
# Epoch 55/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.2232 - accuracy: 0.9190 - val_loss: 2.5214 - val_accuracy: 0.5264
# Epoch 56/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.2076 - accuracy: 0.9227 - val_loss: 10.0420 - val_accuracy: 0.1481
# Epoch 57/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.2314 - accuracy: 0.9139 - val_loss: 9.0922 - val_accuracy: 0.2522
# Epoch 58/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2304 - accuracy: 0.9201 - val_loss: 4.9036 - val_accuracy: 0.5865
# Epoch 59/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.2211 - accuracy: 0.9120 - val_loss: 10.3689 - val_accuracy: 0.1994
# Epoch 60/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2057 - accuracy: 0.9234 - val_loss: 0.6160 - val_accuracy: 0.8079
# Epoch 61/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.2343 - accuracy: 0.9109 - val_loss: 1.4239 - val_accuracy: 0.6378
# Epoch 62/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2180 - accuracy: 0.9179 - val_loss: 6.6261 - val_accuracy: 0.3138
# Epoch 63/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.2560 - accuracy: 0.9036 - val_loss: 88.6006 - val_accuracy: 0.0352
# Epoch 64/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.2344 - accuracy: 0.9131 - val_loss: 15.3017 - val_accuracy: 0.1085
# Epoch 65/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2151 - accuracy: 0.9186 - val_loss: 1.3251 - val_accuracy: 0.6510
# Epoch 66/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.2447 - accuracy: 0.9102 - val_loss: 0.8790 - val_accuracy: 0.7287
# Epoch 67/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.2237 - accuracy: 0.9219 - val_loss: 5.5301 - val_accuracy: 0.3490
# Epoch 68/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.2083 - accuracy: 0.9208 - val_loss: 11.9102 - val_accuracy: 0.2082
# Epoch 69/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1946 - accuracy: 0.9289 - val_loss: 10.2845 - val_accuracy: 0.1452
# Epoch 70/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2031 - accuracy: 0.9274 - val_loss: 0.6102 - val_accuracy: 0.8094
# Epoch 71/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1997 - accuracy: 0.9252 - val_loss: 5.5991 - val_accuracy: 0.3358
# Epoch 72/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2117 - accuracy: 0.9135 - val_loss: 18.2651 - val_accuracy: 0.0850
# Epoch 73/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.2055 - accuracy: 0.9227 - val_loss: 44.3702 - val_accuracy: 0.0880
# Epoch 74/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1965 - accuracy: 0.9296 - val_loss: 4.2964 - val_accuracy: 0.4252
# Epoch 75/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.2026 - accuracy: 0.9278 - val_loss: 3.5533 - val_accuracy: 0.7625
# Epoch 76/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.2135 - accuracy: 0.9186 - val_loss: 23.2595 - val_accuracy: 0.0762
# Epoch 77/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1818 - accuracy: 0.9271 - val_loss: 26.0666 - val_accuracy: 0.0924
# Epoch 78/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1836 - accuracy: 0.9274 - val_loss: 1.8049 - val_accuracy: 0.6320
# Epoch 79/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1752 - accuracy: 0.9274 - val_loss: 0.7401 - val_accuracy: 0.7918
# Epoch 80/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1925 - accuracy: 0.9267 - val_loss: 10.9553 - val_accuracy: 0.2141
# Epoch 81/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1772 - accuracy: 0.9304 - val_loss: 5.9286 - val_accuracy: 0.3270
# Epoch 82/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1938 - accuracy: 0.9252 - val_loss: 1.3332 - val_accuracy: 0.6628
# Epoch 83/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1963 - accuracy: 0.9223 - val_loss: 2.3027 - val_accuracy: 0.7419
# Epoch 84/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.2152 - accuracy: 0.9212 - val_loss: 14.2376 - val_accuracy: 0.0909
# Epoch 85/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1950 - accuracy: 0.9260 - val_loss: 14.8513 - val_accuracy: 0.0880
# Epoch 86/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1862 - accuracy: 0.9311 - val_loss: 0.6164 - val_accuracy: 0.8196
# Epoch 87/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1850 - accuracy: 0.9329 - val_loss: 14.8262 - val_accuracy: 0.1716
# Epoch 88/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1930 - accuracy: 0.9285 - val_loss: 4.5825 - val_accuracy: 0.3812
# Epoch 89/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1808 - accuracy: 0.9307 - val_loss: 3.4395 - val_accuracy: 0.4897
# Epoch 90/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1758 - accuracy: 0.9318 - val_loss: 3.9262 - val_accuracy: 0.4208
# Epoch 91/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1704 - accuracy: 0.9311 - val_loss: 17.7119 - val_accuracy: 0.1100
# Epoch 92/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1754 - accuracy: 0.9311 - val_loss: 0.8685 - val_accuracy: 0.7713
# Epoch 93/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1748 - accuracy: 0.9307 - val_loss: 1.8675 - val_accuracy: 0.7038
# Epoch 94/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1691 - accuracy: 0.9391 - val_loss: 10.9525 - val_accuracy: 0.2185
# Epoch 95/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1684 - accuracy: 0.9355 - val_loss: 0.5507 - val_accuracy: 0.8314
# Epoch 96/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1691 - accuracy: 0.9307 - val_loss: 23.7696 - val_accuracy: 0.1188
# Epoch 97/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1678 - accuracy: 0.9377 - val_loss: 3.5540 - val_accuracy: 0.5674
# Epoch 98/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1647 - accuracy: 0.9380 - val_loss: 4.6188 - val_accuracy: 0.4370
# Epoch 99/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1618 - accuracy: 0.9355 - val_loss: 10.3246 - val_accuracy: 0.2302
# Epoch 100/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1602 - accuracy: 0.9377 - val_loss: 21.2852 - val_accuracy: 0.1290
# Epoch 101/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1540 - accuracy: 0.9380 - val_loss: 5.6827 - val_accuracy: 0.3578
# Epoch 102/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1704 - accuracy: 0.9344 - val_loss: 9.3251 - val_accuracy: 0.5513
# Epoch 103/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1725 - accuracy: 0.9326 - val_loss: 26.5265 - val_accuracy: 0.0997
# Epoch 104/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1534 - accuracy: 0.9351 - val_loss: 22.1655 - val_accuracy: 0.1202
# Epoch 105/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1839 - accuracy: 0.9282 - val_loss: 10.3797 - val_accuracy: 0.2757
# Epoch 106/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1657 - accuracy: 0.9362 - val_loss: 4.3331 - val_accuracy: 0.4062
# Epoch 107/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1751 - accuracy: 0.9318 - val_loss: 13.1324 - val_accuracy: 0.1217
# Epoch 108/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1477 - accuracy: 0.9395 - val_loss: 8.2498 - val_accuracy: 0.2742
# Epoch 109/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1634 - accuracy: 0.9373 - val_loss: 0.4658 - val_accuracy: 0.8402
# Epoch 110/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1489 - accuracy: 0.9476 - val_loss: 11.9942 - val_accuracy: 0.1672
# Epoch 111/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1536 - accuracy: 0.9362 - val_loss: 0.7626 - val_accuracy: 0.8050
# Epoch 112/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1669 - accuracy: 0.9333 - val_loss: 0.5619 - val_accuracy: 0.8240
# Epoch 113/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1634 - accuracy: 0.9373 - val_loss: 21.1344 - val_accuracy: 0.1246
# Epoch 114/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1456 - accuracy: 0.9421 - val_loss: 1.3889 - val_accuracy: 0.6628
# Epoch 115/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1550 - accuracy: 0.9435 - val_loss: 3.8062 - val_accuracy: 0.4340
# Epoch 116/300
# 86/86 [==============================] - 5s 55ms/step - loss: 0.1518 - accuracy: 0.9373 - val_loss: 4.5688 - val_accuracy: 0.3622
# Epoch 117/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1609 - accuracy: 0.9366 - val_loss: 3.7554 - val_accuracy: 0.4545
# Epoch 118/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1598 - accuracy: 0.9395 - val_loss: 10.1213 - val_accuracy: 0.1965
# Epoch 119/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1446 - accuracy: 0.9443 - val_loss: 0.6551 - val_accuracy: 0.7991
# Epoch 120/300
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1487 - accuracy: 0.9439 - val_loss: 0.9294 - val_accuracy: 0.7947
# Epoch 121/300
# 86/86 [==============================] - 5s 55ms/step - loss: 0.1701 - accuracy: 0.9318 - val_loss: 29.1842 - val_accuracy: 0.0806
# Epoch 122/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1594 - accuracy: 0.9406 - val_loss: 7.6175 - val_accuracy: 0.2815
# Epoch 123/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1618 - accuracy: 0.9388 - val_loss: 38.0544 - val_accuracy: 0.0689
# Epoch 124/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1460 - accuracy: 0.9446 - val_loss: 1.2131 - val_accuracy: 0.7126
# Epoch 125/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1302 - accuracy: 0.9509 - val_loss: 11.7994 - val_accuracy: 0.2023
# Epoch 126/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1487 - accuracy: 0.9391 - val_loss: 17.7960 - val_accuracy: 0.1628
# Epoch 127/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1591 - accuracy: 0.9384 - val_loss: 3.7009 - val_accuracy: 0.4971
# Epoch 128/300
# 86/86 [==============================] - 4s 44ms/step - loss: 0.1492 - accuracy: 0.9432 - val_loss: 9.9166 - val_accuracy: 0.2449
# Epoch 129/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1381 - accuracy: 0.9472 - val_loss: 18.7316 - val_accuracy: 0.1056
# Epoch 130/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1449 - accuracy: 0.9391 - val_loss: 14.9316 - val_accuracy: 0.1217
# Epoch 131/300
# 86/86 [==============================] - 4s 51ms/step - loss: 0.1445 - accuracy: 0.9450 - val_loss: 17.7624 - val_accuracy: 0.1334
# Epoch 132/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1450 - accuracy: 0.9417 - val_loss: 20.3542 - val_accuracy: 0.1041
# Epoch 133/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1318 - accuracy: 0.9487 - val_loss: 5.5731 - val_accuracy: 0.3490
# Epoch 134/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1252 - accuracy: 0.9509 - val_loss: 0.9491 - val_accuracy: 0.7595
# Epoch 135/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1410 - accuracy: 0.9446 - val_loss: 12.2274 - val_accuracy: 0.1891
# Epoch 136/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1618 - accuracy: 0.9344 - val_loss: 0.9253 - val_accuracy: 0.7713
# Epoch 137/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1815 - accuracy: 0.9333 - val_loss: 22.0833 - val_accuracy: 0.1188
# Epoch 138/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1613 - accuracy: 0.9446 - val_loss: 2.4886 - val_accuracy: 0.5982
# Epoch 139/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1558 - accuracy: 0.9399 - val_loss: 2.0777 - val_accuracy: 0.6085
# Epoch 140/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1396 - accuracy: 0.9494 - val_loss: 3.1696 - val_accuracy: 0.5352
# Epoch 141/300
# 86/86 [==============================] - 4s 44ms/step - loss: 0.1623 - accuracy: 0.9384 - val_loss: 11.0897 - val_accuracy: 0.1848
# Epoch 142/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1448 - accuracy: 0.9450 - val_loss: 10.7772 - val_accuracy: 0.2053
# Epoch 143/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1492 - accuracy: 0.9380 - val_loss: 5.3569 - val_accuracy: 0.5997
# Epoch 144/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1414 - accuracy: 0.9512 - val_loss: 17.5380 - val_accuracy: 0.2493
# Epoch 145/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1330 - accuracy: 0.9461 - val_loss: 1.9958 - val_accuracy: 0.5938
# Epoch 146/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1223 - accuracy: 0.9520 - val_loss: 23.0348 - val_accuracy: 0.1070
# Epoch 147/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1298 - accuracy: 0.9520 - val_loss: 0.4911 - val_accuracy: 0.8431
# Epoch 148/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1415 - accuracy: 0.9443 - val_loss: 9.3196 - val_accuracy: 0.2786
# Epoch 149/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1382 - accuracy: 0.9454 - val_loss: 2.5888 - val_accuracy: 0.6994
# Epoch 150/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1528 - accuracy: 0.9406 - val_loss: 12.1086 - val_accuracy: 0.2273
# Epoch 151/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1388 - accuracy: 0.9428 - val_loss: 0.8231 - val_accuracy: 0.7889
# Epoch 152/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1427 - accuracy: 0.9465 - val_loss: 33.1789 - val_accuracy: 0.0616
# Epoch 153/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1421 - accuracy: 0.9446 - val_loss: 6.7647 - val_accuracy: 0.5806
# Epoch 154/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1372 - accuracy: 0.9454 - val_loss: 14.1367 - val_accuracy: 0.2874
# Epoch 155/300
# 86/86 [==============================] - 5s 54ms/step - loss: 0.1363 - accuracy: 0.9494 - val_loss: 20.6644 - val_accuracy: 0.1349
# Epoch 156/300
# 86/86 [==============================] - 6s 70ms/step - loss: 0.1191 - accuracy: 0.9549 - val_loss: 9.0238 - val_accuracy: 0.2581
# Epoch 157/300
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1591 - accuracy: 0.9370 - val_loss: 47.5921 - val_accuracy: 0.0381
# Epoch 158/300
# 86/86 [==============================] - 6s 64ms/step - loss: 0.1420 - accuracy: 0.9465 - val_loss: 11.4529 - val_accuracy: 0.1935
# Epoch 159/300
# 86/86 [==============================] - 5s 64ms/step - loss: 0.1414 - accuracy: 0.9424 - val_loss: 1.9297 - val_accuracy: 0.7023
# Epoch 160/300
# 86/86 [==============================] - 5s 63ms/step - loss: 0.1374 - accuracy: 0.9454 - val_loss: 21.7342 - val_accuracy: 0.1320
# Epoch 161/300
# 86/86 [==============================] - 6s 68ms/step - loss: 0.1369 - accuracy: 0.9498 - val_loss: 32.5959 - val_accuracy: 0.0806
# Epoch 162/300
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1509 - accuracy: 0.9399 - val_loss: 0.6075 - val_accuracy: 0.8240
# Epoch 163/300
# 86/86 [==============================] - 6s 69ms/step - loss: 0.1553 - accuracy: 0.9388 - val_loss: 0.9559 - val_accuracy: 0.7463
# Epoch 164/300
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1334 - accuracy: 0.9454 - val_loss: 3.7961 - val_accuracy: 0.4091
# Epoch 165/300
# 86/86 [==============================] - 5s 63ms/step - loss: 0.1435 - accuracy: 0.9432 - val_loss: 4.1713 - val_accuracy: 0.5953
# Epoch 166/300
# 86/86 [==============================] - 5s 54ms/step - loss: 0.1382 - accuracy: 0.9472 - val_loss: 24.0228 - val_accuracy: 0.1041
# Epoch 167/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1378 - accuracy: 0.9472 - val_loss: 11.6699 - val_accuracy: 0.2170
# Epoch 168/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1393 - accuracy: 0.9439 - val_loss: 15.1966 - val_accuracy: 0.1496
# Epoch 169/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1457 - accuracy: 0.9410 - val_loss: 26.3673 - val_accuracy: 0.2830
# Epoch 170/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1241 - accuracy: 0.9534 - val_loss: 2.6536 - val_accuracy: 0.5924
# Epoch 171/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1259 - accuracy: 0.9553 - val_loss: 1.5314 - val_accuracy: 0.7625
# Epoch 172/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1266 - accuracy: 0.9531 - val_loss: 6.8531 - val_accuracy: 0.3431
# Epoch 173/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1281 - accuracy: 0.9516 - val_loss: 3.7700 - val_accuracy: 0.4663
# Epoch 174/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1368 - accuracy: 0.9454 - val_loss: 8.4629 - val_accuracy: 0.2375
# Epoch 175/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1309 - accuracy: 0.9494 - val_loss: 10.5045 - val_accuracy: 0.2082
# Epoch 176/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1187 - accuracy: 0.9538 - val_loss: 9.6633 - val_accuracy: 0.2243
# Epoch 177/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1413 - accuracy: 0.9417 - val_loss: 1.6672 - val_accuracy: 0.7507
# Epoch 178/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1228 - accuracy: 0.9450 - val_loss: 1.7510 - val_accuracy: 0.6628
# Epoch 179/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1277 - accuracy: 0.9483 - val_loss: 4.0194 - val_accuracy: 0.4472
# Epoch 180/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1148 - accuracy: 0.9556 - val_loss: 0.8239 - val_accuracy: 0.7918
# Epoch 181/300
# 86/86 [==============================] - 4s 44ms/step - loss: 0.1309 - accuracy: 0.9512 - val_loss: 1.4366 - val_accuracy: 0.6818
# Epoch 182/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1279 - accuracy: 0.9509 - val_loss: 4.2094 - val_accuracy: 0.4208
# Epoch 183/300
# 86/86 [==============================] - 4s 44ms/step - loss: 0.1226 - accuracy: 0.9483 - val_loss: 34.8329 - val_accuracy: 0.0484
# Epoch 184/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1218 - accuracy: 0.9545 - val_loss: 48.8753 - val_accuracy: 0.0513
# Epoch 185/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1308 - accuracy: 0.9527 - val_loss: 1.4389 - val_accuracy: 0.6686
# Epoch 186/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1312 - accuracy: 0.9494 - val_loss: 2.3622 - val_accuracy: 0.6628
# Epoch 187/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1200 - accuracy: 0.9538 - val_loss: 9.6901 - val_accuracy: 0.2419
# Epoch 188/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1303 - accuracy: 0.9498 - val_loss: 6.3261 - val_accuracy: 0.3710
# Epoch 189/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1254 - accuracy: 0.9479 - val_loss: 4.2695 - val_accuracy: 0.4296
# Epoch 190/300
# 86/86 [==============================] - 5s 57ms/step - loss: 0.1233 - accuracy: 0.9512 - val_loss: 0.9127 - val_accuracy: 0.7654
# Epoch 191/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1383 - accuracy: 0.9465 - val_loss: 23.1738 - val_accuracy: 0.0938
# Epoch 192/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1322 - accuracy: 0.9509 - val_loss: 0.5312 - val_accuracy: 0.8490
# Epoch 193/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1219 - accuracy: 0.9505 - val_loss: 0.8766 - val_accuracy: 0.7757
# Epoch 194/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1160 - accuracy: 0.9531 - val_loss: 2.3402 - val_accuracy: 0.6452
# Epoch 195/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1255 - accuracy: 0.9527 - val_loss: 0.6405 - val_accuracy: 0.8211
# Epoch 196/300
# 86/86 [==============================] - 4s 43ms/step - loss: 0.1309 - accuracy: 0.9527 - val_loss: 1.7007 - val_accuracy: 0.6613
# Epoch 197/300
# 86/86 [==============================] - 4s 45ms/step - loss: 0.1268 - accuracy: 0.9457 - val_loss: 0.7245 - val_accuracy: 0.8358
# Epoch 198/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1274 - accuracy: 0.9494 - val_loss: 0.9072 - val_accuracy: 0.8416
# Epoch 199/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1125 - accuracy: 0.9567 - val_loss: 13.9335 - val_accuracy: 0.1613
# Epoch 200/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1333 - accuracy: 0.9494 - val_loss: 1.2406 - val_accuracy: 0.7009
# Epoch 201/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1141 - accuracy: 0.9545 - val_loss: 2.0392 - val_accuracy: 0.6012
# Epoch 202/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1198 - accuracy: 0.9523 - val_loss: 0.7577 - val_accuracy: 0.8050
# Epoch 203/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1264 - accuracy: 0.9509 - val_loss: 3.6956 - val_accuracy: 0.4707
# Epoch 204/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1207 - accuracy: 0.9494 - val_loss: 0.6169 - val_accuracy: 0.8299
# Epoch 205/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1209 - accuracy: 0.9553 - val_loss: 6.7197 - val_accuracy: 0.3182
# Epoch 206/300
# 86/86 [==============================] - 4s 44ms/step - loss: 0.1162 - accuracy: 0.9553 - val_loss: 4.6814 - val_accuracy: 0.4340
# Epoch 207/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1150 - accuracy: 0.9553 - val_loss: 17.9938 - val_accuracy: 0.4223
# Epoch 208/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1199 - accuracy: 0.9512 - val_loss: 33.1274 - val_accuracy: 0.0792
# Epoch 209/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1338 - accuracy: 0.9501 - val_loss: 14.0307 - val_accuracy: 0.1818
# Epoch 210/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1243 - accuracy: 0.9516 - val_loss: 21.7192 - val_accuracy: 0.0938
# Epoch 211/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1185 - accuracy: 0.9516 - val_loss: 28.4736 - val_accuracy: 0.0894
# Epoch 212/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1204 - accuracy: 0.9534 - val_loss: 123.3000 - val_accuracy: 0.0455
# Epoch 213/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1310 - accuracy: 0.9538 - val_loss: 20.2372 - val_accuracy: 0.1437
# Epoch 214/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1251 - accuracy: 0.9534 - val_loss: 2.5261 - val_accuracy: 0.5323
# Epoch 215/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1291 - accuracy: 0.9487 - val_loss: 8.2309 - val_accuracy: 0.4707
# Epoch 216/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1324 - accuracy: 0.9450 - val_loss: 44.4974 - val_accuracy: 0.0748
# Epoch 217/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1355 - accuracy: 0.9472 - val_loss: 29.0003 - val_accuracy: 0.0806
# Epoch 218/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1051 - accuracy: 0.9564 - val_loss: 6.0208 - val_accuracy: 0.3974
# Epoch 219/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1076 - accuracy: 0.9549 - val_loss: 0.7927 - val_accuracy: 0.7815
# Epoch 220/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1171 - accuracy: 0.9531 - val_loss: 15.0282 - val_accuracy: 0.1364
# Epoch 221/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1014 - accuracy: 0.9564 - val_loss: 9.2779 - val_accuracy: 0.2390
# Epoch 222/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1116 - accuracy: 0.9560 - val_loss: 3.9770 - val_accuracy: 0.5748
# Epoch 223/300
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0988 - accuracy: 0.9604 - val_loss: 18.2323 - val_accuracy: 0.1994
# Epoch 224/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1198 - accuracy: 0.9542 - val_loss: 32.3312 - val_accuracy: 0.0953
# Epoch 225/300
# 86/86 [==============================] - 5s 54ms/step - loss: 0.1163 - accuracy: 0.9597 - val_loss: 10.0745 - val_accuracy: 0.2566
# Epoch 226/300
# 86/86 [==============================] - 5s 53ms/step - loss: 0.1043 - accuracy: 0.9556 - val_loss: 14.6041 - val_accuracy: 0.1979
# Epoch 227/300
# 86/86 [==============================] - 6s 72ms/step - loss: 0.1076 - accuracy: 0.9549 - val_loss: 16.6342 - val_accuracy: 0.1584
# Epoch 228/300
# 86/86 [==============================] - 6s 73ms/step - loss: 0.1135 - accuracy: 0.9578 - val_loss: 23.3827 - val_accuracy: 0.1129
# Epoch 229/300
# 86/86 [==============================] - 5s 60ms/step - loss: 0.1125 - accuracy: 0.9582 - val_loss: 1.1821 - val_accuracy: 0.7405
# Epoch 230/300
# 86/86 [==============================] - 4s 52ms/step - loss: 0.1118 - accuracy: 0.9567 - val_loss: 0.8031 - val_accuracy: 0.8314
# Epoch 231/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1149 - accuracy: 0.9512 - val_loss: 9.5619 - val_accuracy: 0.2713
# Epoch 232/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1086 - accuracy: 0.9534 - val_loss: 18.4013 - val_accuracy: 0.2815
# Epoch 233/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1143 - accuracy: 0.9538 - val_loss: 11.3736 - val_accuracy: 0.2434
# Epoch 234/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1096 - accuracy: 0.9600 - val_loss: 2.3135 - val_accuracy: 0.5821
# Epoch 235/300
# 86/86 [==============================] - 4s 46ms/step - loss: 0.1162 - accuracy: 0.9538 - val_loss: 1.2839 - val_accuracy: 0.7009
# Epoch 236/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1195 - accuracy: 0.9523 - val_loss: 1.0269 - val_accuracy: 0.7595
# Epoch 237/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1090 - accuracy: 0.9600 - val_loss: 1.6189 - val_accuracy: 0.6862
# Epoch 238/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1027 - accuracy: 0.9571 - val_loss: 1.9025 - val_accuracy: 0.7903
# Epoch 239/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1339 - accuracy: 0.9479 - val_loss: 3.4580 - val_accuracy: 0.4912
# Epoch 240/300
# 86/86 [==============================] - 5s 52ms/step - loss: 0.1207 - accuracy: 0.9512 - val_loss: 25.6522 - val_accuracy: 0.3416
# Epoch 241/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1094 - accuracy: 0.9553 - val_loss: 15.3023 - val_accuracy: 0.1584
# Epoch 242/300
# 86/86 [==============================] - 5s 52ms/step - loss: 0.1157 - accuracy: 0.9538 - val_loss: 1.1989 - val_accuracy: 0.7273
# Epoch 243/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1181 - accuracy: 0.9531 - val_loss: 37.7520 - val_accuracy: 0.0601
# Epoch 244/300
# 86/86 [==============================] - 5s 53ms/step - loss: 0.1021 - accuracy: 0.9644 - val_loss: 5.2493 - val_accuracy: 0.3724
# Epoch 245/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1069 - accuracy: 0.9538 - val_loss: 0.7274 - val_accuracy: 0.7889
# Epoch 246/300
# 86/86 [==============================] - 4s 51ms/step - loss: 0.1075 - accuracy: 0.9589 - val_loss: 0.5214 - val_accuracy: 0.8460
# Epoch 247/300
# 86/86 [==============================] - 4s 51ms/step - loss: 0.1121 - accuracy: 0.9560 - val_loss: 7.6758 - val_accuracy: 0.5748
# Epoch 248/300
# 86/86 [==============================] - 5s 52ms/step - loss: 0.1102 - accuracy: 0.9575 - val_loss: 18.7261 - val_accuracy: 0.1188
# Epoch 249/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1085 - accuracy: 0.9582 - val_loss: 0.9311 - val_accuracy: 0.7815
# Epoch 250/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1058 - accuracy: 0.9567 - val_loss: 1.2046 - val_accuracy: 0.7273
# Epoch 251/300
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0992 - accuracy: 0.9593 - val_loss: 27.4593 - val_accuracy: 0.2771
# Epoch 252/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1176 - accuracy: 0.9571 - val_loss: 1.2312 - val_accuracy: 0.7434
# Epoch 253/300
# 86/86 [==============================] - 5s 55ms/step - loss: 0.0990 - accuracy: 0.9622 - val_loss: 15.2804 - val_accuracy: 0.1642
# Epoch 254/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.0934 - accuracy: 0.9644 - val_loss: 0.6086 - val_accuracy: 0.8431
# Epoch 255/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.0924 - accuracy: 0.9641 - val_loss: 0.4951 - val_accuracy: 0.8607
# Epoch 256/300
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0896 - accuracy: 0.9633 - val_loss: 1.8975 - val_accuracy: 0.6510
# Epoch 257/300
# 86/86 [==============================] - 5s 53ms/step - loss: 0.0971 - accuracy: 0.9622 - val_loss: 3.2176 - val_accuracy: 0.5308
# Epoch 258/300
# 86/86 [==============================] - 4s 51ms/step - loss: 0.1067 - accuracy: 0.9586 - val_loss: 17.7049 - val_accuracy: 0.1628
# Epoch 259/300
# 86/86 [==============================] - 4s 52ms/step - loss: 0.1113 - accuracy: 0.9586 - val_loss: 1.4521 - val_accuracy: 0.6950
# Epoch 260/300
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1080 - accuracy: 0.9571 - val_loss: 1.7522 - val_accuracy: 0.6672
# Epoch 261/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1211 - accuracy: 0.9538 - val_loss: 4.2541 - val_accuracy: 0.5015
# Epoch 262/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1025 - accuracy: 0.9586 - val_loss: 1.5551 - val_accuracy: 0.7375
# Epoch 263/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1006 - accuracy: 0.9600 - val_loss: 0.8901 - val_accuracy: 0.7683
# Epoch 264/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1019 - accuracy: 0.9633 - val_loss: 1.5296 - val_accuracy: 0.6760
# Epoch 265/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1066 - accuracy: 0.9575 - val_loss: 2.7143 - val_accuracy: 0.5704
# Epoch 266/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1101 - accuracy: 0.9575 - val_loss: 7.4481 - val_accuracy: 0.3196
# Epoch 267/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1099 - accuracy: 0.9523 - val_loss: 0.8034 - val_accuracy: 0.7947
# Epoch 268/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.0985 - accuracy: 0.9608 - val_loss: 19.9295 - val_accuracy: 0.1393
# Epoch 269/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.0986 - accuracy: 0.9586 - val_loss: 6.5414 - val_accuracy: 0.5909
# Epoch 270/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1042 - accuracy: 0.9597 - val_loss: 22.1917 - val_accuracy: 0.0938
# Epoch 271/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1050 - accuracy: 0.9575 - val_loss: 1.2447 - val_accuracy: 0.7302
# Epoch 272/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1109 - accuracy: 0.9560 - val_loss: 1.5630 - val_accuracy: 0.6628
# Epoch 273/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1023 - accuracy: 0.9597 - val_loss: 3.9266 - val_accuracy: 0.4839
# Epoch 274/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1019 - accuracy: 0.9619 - val_loss: 0.7825 - val_accuracy: 0.8065
# Epoch 275/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1130 - accuracy: 0.9553 - val_loss: 1.3009 - val_accuracy: 0.7771
# Epoch 276/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.0960 - accuracy: 0.9615 - val_loss: 1.8374 - val_accuracy: 0.6628
# Epoch 277/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1002 - accuracy: 0.9600 - val_loss: 0.9339 - val_accuracy: 0.8211
# Epoch 278/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.0915 - accuracy: 0.9641 - val_loss: 42.4075 - val_accuracy: 0.0587
# Epoch 279/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1166 - accuracy: 0.9578 - val_loss: 46.2368 - val_accuracy: 0.0587
# Epoch 280/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1067 - accuracy: 0.9556 - val_loss: 1.3792 - val_accuracy: 0.6950
# Epoch 281/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.1063 - accuracy: 0.9597 - val_loss: 12.3673 - val_accuracy: 0.2155
# Epoch 282/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1068 - accuracy: 0.9556 - val_loss: 8.1395 - val_accuracy: 0.2962
# Epoch 283/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1003 - accuracy: 0.9604 - val_loss: 1.9037 - val_accuracy: 0.7757
# Epoch 284/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.0983 - accuracy: 0.9604 - val_loss: 26.4236 - val_accuracy: 0.2199
# Epoch 285/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.1029 - accuracy: 0.9582 - val_loss: 0.9512 - val_accuracy: 0.7830
# Epoch 286/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.0993 - accuracy: 0.9604 - val_loss: 3.0988 - val_accuracy: 0.4853
# Epoch 287/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.0979 - accuracy: 0.9637 - val_loss: 12.8057 - val_accuracy: 0.1862
# Epoch 288/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1090 - accuracy: 0.9593 - val_loss: 10.1527 - val_accuracy: 0.3783
# Epoch 289/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.0930 - accuracy: 0.9637 - val_loss: 0.5959 - val_accuracy: 0.8416
# Epoch 290/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.0881 - accuracy: 0.9648 - val_loss: 0.7032 - val_accuracy: 0.8123
# Epoch 291/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.0949 - accuracy: 0.9604 - val_loss: 3.1753 - val_accuracy: 0.7493
# Epoch 292/300
# 86/86 [==============================] - 4s 52ms/step - loss: 0.1046 - accuracy: 0.9593 - val_loss: 0.6740 - val_accuracy: 0.8226
# Epoch 293/300
# 86/86 [==============================] - 4s 50ms/step - loss: 0.0897 - accuracy: 0.9655 - val_loss: 9.0472 - val_accuracy: 0.2595
# Epoch 294/300
# 86/86 [==============================] - 4s 51ms/step - loss: 0.1025 - accuracy: 0.9593 - val_loss: 1.8156 - val_accuracy: 0.6730
# Epoch 295/300
# 86/86 [==============================] - 4s 47ms/step - loss: 0.0934 - accuracy: 0.9644 - val_loss: 0.8973 - val_accuracy: 0.7625
# Epoch 296/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.0885 - accuracy: 0.9666 - val_loss: 15.8811 - val_accuracy: 0.4150
# Epoch 297/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.0945 - accuracy: 0.9630 - val_loss: 13.0574 - val_accuracy: 0.2258
# Epoch 298/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.0901 - accuracy: 0.9641 - val_loss: 1.5420 - val_accuracy: 0.6789
# Epoch 299/300
# 86/86 [==============================] - 4s 49ms/step - loss: 0.0981 - accuracy: 0.9626 - val_loss: 5.3760 - val_accuracy: 0.3754
# Epoch 300/300
# 86/86 [==============================] - 4s 48ms/step - loss: 0.0787 - accuracy: 0.9696 - val_loss: 0.7815 - val_accuracy: 0.7991
# Evaluate on test data
# 6/6 [==============================] - 0s 37ms/step - loss: 0.7815 - accuracy: 0.7991
# test loss, test accuracy: [0.7814748287200928, 0.7991202473640442]

# %%
# Plot training & validation accuracy values
plt.figure(figsize=[6,4])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=[6,4])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(X_test, y_test, batch_size=128)
print("test loss, test accuracy:", results)
# Out:
# Evaluate on test data
# 6/6 [==============================] - 0s 36ms/step - loss: 0.8965 - accuracy: 0.7874
# test loss, test accuracy: [0.8965067267417908, 0.7873900532722473]

# %%
# #Save Model For Furture Use
# model.save('EpochTenThousand')

# %%
# import pickle

# # Assume you have a history object from model.fit
# # history = model.fit(....)

# # Save it under some name
# with open('trainHistoryDict', 'wb') as file_pi:
#     pickle.dump(history.history, file_pi)

# %%
# with open('trainHistoryDict', 'rb') as file_pi:
#     loaded_history = pickle.load(file_pi)

# %%
# Evaluate the model on the training set
train_loss, train_accuracy = model.evaluate(X_train, y_train)
print("Train Loss:", train_loss)
print("Train Accuracy:", train_accuracy)
# Out:
# 86/86 [==============================] - 1s 12ms/step - loss: 0.3608 - accuracy: 0.8787
# Train Loss: 0.36082106828689575
# Train Accuracy: 0.8786656856536865

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Make predictions on the test set
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Print classification report
print("Classification Report:")
print(classification_report(y_true_labels, y_pred_labels, zero_division=1))

# Print confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)
print("Confusion Matrix:")
print(confusion_mtx)
# Out:
# 22/22 [==============================] - 0s 12ms/step - loss: 0.8965 - accuracy: 0.7874
# Test Loss: 0.896506667137146
# Test Accuracy: 0.7873900532722473
# 22/22 [==============================] - 0s 12ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.28      0.57      0.37        14
#            1       0.62      0.73      0.67        11
#            2       0.50      1.00      0.67        10
#            3       0.94      0.85      0.89        20
#            4       1.00      0.93      0.96        14
#            5       0.92      0.75      0.83        16
#            6       0.89      0.89      0.89         9
#            7       1.00      0.87      0.93        15
#            8       0.79      0.92      0.85        12
#            9       0.91      0.91      0.91        11
#           10       0.84      1.00      0.91        16
#           11       1.00      1.00      1.00         9
#           12       0.71      0.56      0.63         9
#           13       1.00      1.00      1.00        10
#           14       0.93      0.93      0.93        15
#           15       1.00      0.93      0.96        14
#           16       1.00      0.70      0.82        10
#           17       1.00      0.82      0.90        11
#           18       1.00      0.56      0.72        16
#           19       0.80      0.80      0.80         5
#           20       0.86      0.50      0.63        12
#           21       1.00      0.67      0.80         9
#           22       1.00      0.89      0.94         9
#           23       0.86      0.86      0.86         7
#           24       0.53      0.89      0.67         9
#           25       0.67      1.00      0.80         8
#           26       0.87      1.00      0.93        13
#           27       0.89      1.00      0.94         8
#           28       0.55      0.60      0.57        10
#           29       1.00      1.00      1.00        11
#           30       0.67      0.55      0.60        11
#           31       0.89      0.73      0.80        11
#           32       0.89      0.67      0.76        12
#           33       0.90      0.82      0.86        11
#           34       0.88      0.70      0.78        10
#           35       0.83      0.91      0.87        11
#           36       0.68      1.00      0.81        13
#           37       0.67      1.00      0.80         6
#           38       0.42      0.83      0.56         6
#           39       1.00      1.00      1.00         7
#           40       0.92      0.92      0.92        12
#           41       1.00      0.62      0.77         8
#           42       0.52      1.00      0.69        11
#           43       1.00      0.78      0.88         9
#           44       1.00      0.85      0.92        13
#           45       1.00      1.00      1.00         7
#           46       0.70      0.70      0.70        10
#           47       0.89      0.73      0.80        11
#           48       1.00      1.00      1.00        11
#           49       0.92      0.92      0.92        12
#           50       0.44      0.54      0.48        13
#           51       1.00      0.43      0.60         7
#           52       1.00      0.73      0.84        11
#           53       0.89      0.89      0.89         9
#           54       0.52      0.72      0.60        18
#           55       1.00      0.75      0.86        12
#           56       0.80      0.67      0.73        12
#           57       0.56      0.62      0.59         8
#           58       0.78      0.64      0.70        11
#           59       0.91      0.62      0.74        16
#           60       0.67      0.20      0.31        10
#           61       0.75      0.30      0.43        10
#
#     accuracy                           0.79       682
#    macro avg       0.83      0.79      0.79       682
# weighted avg       0.83      0.79      0.79       682
#
# Confusion Matrix:
# [[ 8  0  0 ...  0  0  0]
#  [ 1  8  2 ...  0  0  0]
#  [ 0  0 10 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 10  0  0]
#  [ 0  0  0 ...  0  2  0]
#  [ 0  0  5 ...  0  0  3]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Set the font scale (this will affect heatmap annotation size)
sns.set(font_scale=1.5)

# Adjust size of labels, title using rcParams
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15

# Calculate confusion matrix
confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)

# Visualize confusion matrix using seaborn's heatmap
plt.figure(figsize=(30, 30))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label', fontsize=20)
plt.ylabel('True Label', fontsize=20)
plt.title('Confusion Matrix', fontsize=25)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert probabilities to labels
y_pred_labels = np.argmax(y_pred, axis=1)

# Also convert the one-hot encoded labels back to label encoding
y_true_labels = np.argmax(y_test, axis=1)

# Convert numerical labels back to original labels
y_pred_labels = le.inverse_transform(y_pred_labels)
y_true_labels = le.inverse_transform(y_true_labels)

# Calculate confusion matrix
confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)

# Create a list of unique labels
labels = list(le.classes_)

# Set the font scale (this will affect heatmap annotation size)
sns.set(font_scale=1.5)

# Adjust size of labels, title using rcParams
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15

# Visualize confusion matrix using seaborn's heatmap
plt.figure(figsize=(25, 20))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label', fontsize=20)
plt.ylabel('True Label', fontsize=20)
plt.title('Confusion Matrix', fontsize=25)
plt.show()
