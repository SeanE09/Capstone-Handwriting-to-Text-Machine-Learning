# %%
conda activate TFgpu
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div align="center">
#   <img src="DisplayIMG/Cartoon.png" alt="Image Description" />
# </div>

# %%
import os
import glob
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as s
from PIL import Image
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras_tuner import BayesianOptimization, HyperParameters
import cv2
import tensorflow as tf
import tensorflow.keras.backend as K
import seaborn as sns

# %%
num_cores = os.cpu_count()  # Get number of CPU cores
num_cores_to_use = num_cores // 2  # Use half of the cores

num_cores
# Out:
# 32

# %%
num_cores_to_use
# Out:
# 16

# %% [markdown]
# # Load Data

# %%
current_directory = os.getcwd()

folder_name = "img"

folder_path = os.path.join(current_directory, folder_name)

csv_file_path = os.path.join(current_directory, "labels", "english-clean.csv")

df = pd.read_csv(csv_file_path)

# Create a dictionary where keys are filenames and values are labels
labels_dict = df.set_index('image')['label'].to_dict()

# %% [markdown]
# # Helper Function for Loading Images

# %%
def load_images_from_folder(folder, labels_dict):
    images = []
    labels = []
    for file_path in glob.glob(os.path.join(folder, "*.png")):
        img = Image.open(file_path)
        if img is not None:
            img = img.convert('L')  # Convert image to grayscale
            img = img.resize((64, 64))  # Resize the image to your desired size
            np_img = np.array(img)
            images.append(np_img)
            filename = os.path.basename(file_path)
            label = labels_dict[filename]  # Get the label from the filename
            labels.append(label)
    return images, labels


images, labels = load_images_from_folder(folder_path, labels_dict)

le = preprocessing.LabelEncoder()
numerical_labels = le.fit_transform(labels)  # Convert labels to integers

images = np.array(images)  # Convert list of arrays to a single array
mean = np.mean(images)
std = np.std(images)
images = (images - mean) / std  # Normalize pixel values
images = images.reshape(-1, 64, 64, 1)  # Reshape array for CNN

encoded_labels = to_categorical(numerical_labels)  # One-hot encode labels

# %% [markdown]
# # Split and Fit Data

# %% [markdown]
# <div align="center">
#   <img src="DisplayIMG/Split & Fit.png" alt="Image Description" />
# </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(images, encoded_labels, test_size=0.2, random_state=42,
                                                    shuffle=True)

# Data augmentation for training data
datagen = ImageDataGenerator(
    rotation_range=35,  # Rotate images randomly by **% degrees
    width_shift_range=0.1,  # Shift images horizontally by **% of the width
    height_shift_range=0.1,  # Shift images vertically by **% of the height
    shear_range=0.0,  # Apply shear transformation with a shear intensity of **
    zoom_range=0.1,  # Apply zoom transformation with a zoom range of **
    horizontal_flip=False,  # Do not Flip images horizontally
    vertical_flip=False  # Do not flip images vertically
)

datagen.fit(X_train)

# %% [markdown]
# # Build Model

# %% [markdown]
# <div align="center">
#   <img src="DisplayIMG/i_model.png" alt="Image Description" />
# </div>

# %%
lr_decay = ReduceLROnPlateau(factor=0.1, patience=10)



model = Sequential()

# First block of convolutions
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 1)))  #Add Notes here******
model.add(BatchNormalization())                                                            #Add Notes here******
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))                           #Add Notes here******
model.add(BatchNormalization())                                                            
model.add(MaxPooling2D((2, 2)))                                                            #Add Notes here******
model.add(Dropout(0.1))                                                                    #Add Notes here******

# Second block of convolutions
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.1))

# Fully connected layers
model.add(Flatten())                                                                       #Add Notes here******
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(len(le.classes_), activation='softmax'))                                   #Add Notes here******

# Compile model
model.compile(optimizer=Adam(learning_rate=0.01),                                          #Add Notes here******
              loss='categorical_crossentropy',                                             #Add Notes here******
              metrics=['accuracy'])                                                        #Add Notes here******


history = model.fit(datagen.flow(X_train, y_train),
                    steps_per_epoch=len(X_train) // 32,
                    epochs=200,                                                            # Number of Runs in the Model
                    validation_data=(X_test, y_test),
                    callbacks=[lr_decay])                                                  #Add Notes here******
# Out:
# Epoch 1/200
# 85/85 [==============================] - 7s 77ms/step - loss: 4.5855 - accuracy: 0.0629 - val_loss: 22.2581 - val_accuracy: 0.0191 - lr: 0.0100
# Epoch 2/200
# 85/85 [==============================] - 4s 53ms/step - loss: 3.9479 - accuracy: 0.0861 - val_loss: 22.0357 - val_accuracy: 0.0293 - lr: 0.0100
# Epoch 3/200
# 85/85 [==============================] - 4s 50ms/step - loss: 3.4284 - accuracy: 0.1550 - val_loss: 3.6616 - val_accuracy: 0.1349 - lr: 0.0100
# Epoch 4/200
# 85/85 [==============================] - 4s 51ms/step - loss: 3.0897 - accuracy: 0.2081 - val_loss: 34.2629 - val_accuracy: 0.0279 - lr: 0.0100
# Epoch 5/200
# 85/85 [==============================] - 4s 51ms/step - loss: 2.7261 - accuracy: 0.2711 - val_loss: 97.1041 - val_accuracy: 0.0176 - lr: 0.0100
# Epoch 6/200
# 85/85 [==============================] - 4s 52ms/step - loss: 2.3151 - accuracy: 0.3431 - val_loss: 105.6448 - val_accuracy: 0.0235 - lr: 0.0100
# Epoch 7/200
# 85/85 [==============================] - 4s 50ms/step - loss: 1.9889 - accuracy: 0.4306 - val_loss: 49.9300 - val_accuracy: 0.0337 - lr: 0.0100
# Epoch 8/200
# 85/85 [==============================] - 4s 51ms/step - loss: 1.8130 - accuracy: 0.4622 - val_loss: 3.6837 - val_accuracy: 0.2639 - lr: 0.0100
# Epoch 9/200
# 85/85 [==============================] - 4s 49ms/step - loss: 1.7039 - accuracy: 0.4889 - val_loss: 33.3293 - val_accuracy: 0.0997 - lr: 0.0100
# Epoch 10/200
# 85/85 [==============================] - 4s 48ms/step - loss: 1.5582 - accuracy: 0.5441 - val_loss: 274.9203 - val_accuracy: 0.0147 - lr: 0.0100
# Epoch 11/200
# 85/85 [==============================] - 4s 50ms/step - loss: 1.4566 - accuracy: 0.5590 - val_loss: 39.3800 - val_accuracy: 0.0762 - lr: 0.0100
# Epoch 12/200
# 85/85 [==============================] - 4s 50ms/step - loss: 1.7693 - accuracy: 0.5022 - val_loss: 14.4644 - val_accuracy: 0.0865 - lr: 0.0100
# Epoch 13/200
# 85/85 [==============================] - 4s 50ms/step - loss: 1.4877 - accuracy: 0.5523 - val_loss: 3.7344 - val_accuracy: 0.4545 - lr: 0.0100
# Epoch 14/200
# 85/85 [==============================] - 4s 50ms/step - loss: 1.2327 - accuracy: 0.6128 - val_loss: 0.9509 - val_accuracy: 0.6818 - lr: 1.0000e-03
# Epoch 15/200
# 85/85 [==============================] - 4s 50ms/step - loss: 1.1352 - accuracy: 0.6573 - val_loss: 0.9325 - val_accuracy: 0.7038 - lr: 1.0000e-03
# Epoch 16/200
# 85/85 [==============================] - 4s 51ms/step - loss: 1.0992 - accuracy: 0.6569 - val_loss: 0.7352 - val_accuracy: 0.7830 - lr: 1.0000e-03
# Epoch 17/200
# 85/85 [==============================] - 4s 50ms/step - loss: 1.0205 - accuracy: 0.6838 - val_loss: 0.7260 - val_accuracy: 0.7727 - lr: 1.0000e-03
# Epoch 18/200
# 85/85 [==============================] - 4s 50ms/step - loss: 0
200
# 85/85 [==============================] - 4s 50ms/step - loss: 0.6140 - accuracy: 0.7971 - val_loss: 0.5850 - val_accuracy: 0.8255 - lr: 1.0000e-18
# Epoch 195/200
# 85/85 [==============================] - 4s 51ms/step - loss: 0.5770 - accuracy: 0.8201 - val_loss: 0.5844 - val_accuracy: 0.8240 - lr: 1.0000e-18
# Epoch 196/200
# 85/85 [==============================] - 4s 51ms/step - loss: 0.6176 - accuracy: 0.8012 - val_loss: 0.5846 - val_accuracy: 0.8226 - lr: 1.0000e-18
# Epoch 197/200
# 85/85 [==============================] - 4s 50ms/step - loss: 0.6089 - accuracy: 0.8056 - val_loss: 0.5842 - val_accuracy: 0.8255 - lr: 1.0000e-18
# Epoch 198/200
# 85/85 [==============================] - 4s 52ms/step - loss: 0.6176 - accuracy: 0.8042 - val_loss: 0.5853 - val_accuracy: 0.8270 - lr: 1.0000e-18
# Epoch 199/200
# 85/85 [==============================] - 4s 51ms/step - loss: 0.6099 - accuracy: 0.7993 - val_loss: 0.5838 - val_accuracy: 0.8226 - lr: 1.0000e-19
# Epoch 200/200
# 85/85 [==============================] - 4s 51ms/step - loss: 0.6062 - accuracy: 0.8234 - val_loss: 0.5841 - val_accuracy: 0.8255 - lr: 1.0000e-19

# %%
# Evaluate the model on the training set
train_loss, train_accuracy = model.evaluate(X_train, y_train)
print("Train Loss:", train_loss)
print("Train Accuracy:", train_accuracy)
# Out:
# 86/86 [==============================] - 1s 11ms/step - loss: 0.3448 - accuracy: 0.8933
# Train Loss: 0.34476736187934875
# Train Accuracy: 0.8933284282684326

# %% [markdown]
# # Model Architecture Visualization:

# %%
from keras.utils import plot_model

# Generate the plot
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 32)        320
#
#  batch_normalization (BatchN  (None, 64, 64, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 512)               8389120
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 62)                31806
#
# =================================================================
# Total params: 8,488,734
# Trainable params: 8,487,326
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# conv2d
# batch_normalization
# conv2d_1
# batch_normalization_1
# max_pooling2d
# dropout
# conv2d_2
# batch_normalization_2
# conv2d_3
# batch_normalization_3
# max_pooling2d_1
# dropout_1
# flatten
# dense
# batch_normalization_4
# dropout_2
# dense_1

# %% [markdown]
# # Visualize

# %% [markdown]
# <div align="center">
#   <img src="DisplayIMG/Data_Lung.png" alt="Image Description" />
# </div>

# %%
# plt.subplot(1, 2, 1)
# plt.plot(history.history['accuracy'], label='Train Accuracy')
# plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()

# plt.subplot(1, 2, 2)
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()

plt.tight_layout()
plt.show()
[7]
# Make predictions on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Print a classification report
print(classification_report(y_true_classes, y_pred_classes, target_names=le.classes_, zero_division=1))
# Out:
# 22/22 [==============================] - 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       0.50      0.29      0.36        14
#            1       0.44      0.64      0.52        11
#            2       0.90      0.90      0.90        10
#            3       1.00      1.00      1.00        20
#            4       0.93      0.93      0.93        14
#            5       0.92      0.75      0.83        16
#            6       0.67      0.89      0.76         9
#            7       1.00      0.93      0.97        15
#            8       0.64      0.75      0.69        12
#            9       1.00      0.82      0.90        11
#            A       1.00      1.00      1.00        16
#            B       0.89      0.89      0.89         9
#            C       0.86      0.67      0.75         9
#            D       0.83      1.00      0.91        10
#            E       1.00      1.00      1.00        15
#            F       1.00      0.93      0.96        14
#            G       0.89      0.80      0.84        10
#            H       1.00      0.55      0.71        11
#            I       1.00      0.50      0.67        16
#            J       1.00      0.80      0.89         5
#            K       0.78      0.58      0.67        12
#            L       0.89      0.89      0.89         9
#            M       0.80      0.89      0.84         9
#            N       0.78      1.00      0.88         7
#            O       0.47      0.78      0.58         9
#            P       0.89      1.00      0.94         8
#            Q       0.87      1.00      0.93        13
#            R       1.00      0.88      0.93         8
#            S       0.75      0.90      0.82        10
#            T       0.92      1.00      0.96        11
#            U       1.00      0.73      0.84        11
#            V       0.70      0.64      0.67        11
#            W       0.83      0.83      0.83        12
#            X       1.00      0.82      0.90        11
#            Y       0.90      0.90      0.90        10
#            Z       1.00      0.82      0.90        11
#            a       0.90      0.69      0.78        13
#            b       1.00      0.83      0.91         6
#            c       0.56      0.83      0.67         6
#            d       0.88      1.00      0.93         7
#            e       0.86      1.00      0.92        12
#            f       0.62      0.62      0.62         8
#            g       0.65      1.00      0.79        11
#            h       1.00      0.78      0.88         9
#            i       1.00      0.92      0.96        13
#            j       1.00      1.00      1.00         7
#            k       0.58      0.70      0.64        10
#            l       0.62      0.73      0.67        11
#            m       0.90      0.82      0.86        11
#            n       0.86      1.00      0.92        12
#            o       0.67      0.62      0.64        13
#            p       1.00      0.86      0.92         7
#            q       0.89      0.73      0.80        11
#            r       0.73      0.89      0.80         9
#            s       0.88      0.78      0.82        18
#            t       0.85      0.92      0.88        12
#            u       0.85      0.92      0.88        12
#            v       0.58      0.88      0.70         8
#            w       0.75      0.82      0.78        11
#            x       0.91      0.62      0.74        16
#            y       0.90      0.90      0.90        10
#            z       0.59      1.00      0.74        10
#
#     accuracy                           0.83       682
#    macro avg       0.84      0.83      0.82       682
# weighted avg       0.85      0.83      0.83       682

# %%
# Plot training & validation accuracy values
plt.figure(figsize=[12,8])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=[12,8])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(X_test, y_test, batch_size=128)
print("test loss, test accuracy:", results)
# Out:
# Evaluate on test data
# 6/6 [==============================] - 0s 42ms/step - loss: 0.5841 - accuracy: 0.8255
# test loss, test accuracy: [0.5841078162193298, 0.8255131840705872]

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert probabilities to labels
y_pred_labels = np.argmax(y_pred, axis=1)

# Also convert the one-hot encoded labels back to label encoding
y_true_labels = np.argmax(y_test, axis=1)

# Convert numerical labels back to original labels
y_pred_labels = le.inverse_transform(y_pred_labels)
y_true_labels = le.inverse_transform(y_true_labels)

# Calculate confusion matrix
confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)

# Create a list of unique labels
labels = list(le.classes_)

# Set the font scale (this will affect heatmap annotation size)
sns.set(font_scale=1.5)

# Adjust size of labels, title using rcParams
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15

# Visualize confusion matrix using seaborn's heatmap
plt.figure(figsize=(25, 20))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label', fontsize=20)
plt.ylabel('True Label', fontsize=20)
plt.title('Confusion Matrix', fontsize=25)
plt.show()
# Out:
# 22/22 [==============================] - 0s 11ms/step

# %%
# #Save Model For Furture Use
# model.save('EpochTenThousand')

# %%
# import pickle

# # Assume you have a history object from model.fit
# # history = model.fit(....)

# # Save it under some name
# with open('trainHistoryDict', 'wb') as file_pi:
#     pickle.dump(history.history, file_pi)

# %%
# with open('trainHistoryDict', 'rb') as file_pi:
#     loaded_history = pickle.load(file_pi)

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Make predictions on the test set
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Print classification report
print("Classification Report:")
print(classification_report(y_true_labels, y_pred_labels, zero_division=1))

# Print confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)
print("Confusion Matrix:")
print(confusion_mtx)
# Out:
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5841 - accuracy: 0.8255
# Test Loss: 0.5841078758239746
# Test Accuracy: 0.8255131840705872
# 22/22 [==============================] - 0s 12ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.29      0.36        14
#            1       0.44      0.64      0.52        11
#            2       0.90      0.90      0.90        10
#            3       1.00      1.00      1.00        20
#            4       0.93      0.93      0.93        14
#            5       0.92      0.75      0.83        16
#            6       0.67      0.89      0.76         9
#            7       1.00      0.93      0.97        15
#            8       0.64      0.75      0.69        12
#            9       1.00      0.82      0.90        11
#           10       1.00      1.00      1.00        16
#           11       0.89      0.89      0.89         9
#           12       0.86      0.67      0.75         9
#           13       0.83      1.00      0.91        10
#           14       1.00      1.00      1.00        15
#           15       1.00      0.93      0.96        14
#           16       0.89      0.80      0.84        10
#           17       1.00      0.55      0.71        11
#           18       1.00      0.50      0.67        16
#           19       1.00      0.80      0.89         5
#           20       0.78      0.58      0.67        12
#           21       0.89      0.89      0.89         9
#           22       0.80      0.89      0.84         9
#           23       0.78      1.00      0.88         7
#           24       0.47      0.78      0.58         9
#           25       0.89      1.00      0.94         8
#           26       0.87      1.00      0.93        13
#           27       1.00      0.88      0.93         8
#           28       0.75      0.90      0.82        10
#           29       0.92      1.00      0.96        11
#           30       1.00      0.73      0.84        11
#           31       0.70      0.64      0.67        11
#           32       0.83      0.83      0.83        12
#           33       1.00      0.82      0.90        11
#           34       0.90      0.90      0.90        10
#           35       1.00      0.82      0.90        11
#           36       0.90      0.69      0.78        13
#           37       1.00      0.83      0.91         6
#           38       0.56      0.83      0.67         6
#           39       0.88      1.00      0.93         7
#           40       0.86      1.00      0.92        12
#           41       0.62      0.62      0.62         8
#           42       0.65      1.00      0.79        11
#           43       1.00      0.78      0.88         9
#           44       1.00      0.92      0.96        13
#           45       1.00      1.00      1.00         7
#           46       0.58      0.70      0.64        10
#           47       0.62      0.73      0.67        11
#           48       0.90      0.82      0.86        11
#           49       0.86      1.00      0.92        12
#           50       0.67      0.62      0.64        13
#           51       1.00      0.86      0.92         7
#           52       0.89      0.73      0.80        11
#           53       0.73      0.89      0.80         9
#           54       0.88      0.78      0.82        18
#           55       0.85      0.92      0.88        12
#           56       0.85      0.92      0.88        12
#           57       0.58      0.88      0.70         8
#           58       0.75      0.82      0.78        11
#           59       0.91      0.62      0.74        16
#           60       0.90      0.90      0.90        10
#           61       0.59      1.00      0.74        10
#
#     accuracy                           0.83       682
#    macro avg       0.84      0.83      0.82       682
# weighted avg       0.85      0.83      0.83       682
#
# Confusion Matrix:
# [[ 4  0  0 ...  0  0  0]
#  [ 0  7  1 ...  0  0  0]
#  [ 0  0  9 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 10  0  2]
#  [ 0  0  0 ...  0  9  0]
#  [ 0  0  0 ...  0  0 10]]

# %% [markdown]
# # Class Activation Maps (CAM):

# %%
import numpy as np
import tensorflow.keras.backend as K

def visualize_cam(model, img):
    # Extract the last convolutional layer
    last_conv_layer = model.get_layer('conv2d_3')
    
    # Define a new model that outputs the last conv layer and the model's predicted class probabilities
    cam_model = tf.keras.Model(model.input, (last_conv_layer.output, model.output))
    
    # Calculate the gradients of the predicted class with respect to the output feature map of the last conv layer
    with tf.GradientTape() as tape:
        conv_outputs, predictions = cam_model(img)
        predicted_class = tf.argmax(predictions[0])
        gradient = tape.gradient(predictions[:, predicted_class], conv_outputs)
    
    # Compute the weights using global average pooling on the gradients
    weights = tf.reduce_mean(gradient[0], axis=(0, 1))
    
    # Get the feature map values and resize them to match the input image size
    feature_map = conv_outputs[0]
    cam = np.dot(feature_map, weights)
    cam = cv2.resize(cam, (img.shape[2], img.shape[1]))
    cam = np.maximum(cam, 0)
    cam = cam / np.max(cam)
    
    return cam


# Choose an image from the test set
test_image = X_test[4]

# Reshape the image to match the input shape of the model
test_image = np.reshape(test_image, (1, 64, 64, 1))

# Generate the CAM for the chosen image
cam = visualize_cam(model, test_image)

# Plot the original image and the CAM
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.imshow(cam, cmap='jet', alpha=0.5)
plt.title('Class Activation Map')

plt.tight_layout()
plt.show()

# %%
def visualize_cam(model, img):
    # Extract the last convolutional layer
    last_conv_layer = model.get_layer('conv2d_3')
    
    # Define a new model that outputs the last conv layer and the model's predicted class probabilities
    cam_model = tf.keras.Model(model.input, (last_conv_layer.output, model.output))
    
    # Calculate the gradients of the predicted class with respect to the output feature map of the last conv layer
    with tf.GradientTape() as tape:
        conv_outputs, predictions = cam_model(img)
        predicted_class = tf.argmax(predictions[0])
        gradient = tape.gradient(predictions[:, predicted_class], conv_outputs)
    
    # Compute the weights using global average pooling on the gradients
    weights = tf.reduce_mean(gradient[0], axis=(0, 1))
    
    # Get the feature map values and resize them to match the input image size
    feature_map = conv_outputs[0]
    cam = np.dot(feature_map, weights)
    cam = cv2.resize(cam, (img.shape[2], img.shape[1]))
    cam = np.maximum(cam, 0)
    cam = cam / np.max(cam)
    
    return cam

# %%
cam = visualize_cam(model, test_image)

# Plot the original image and the CAM
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.imshow(cam, cmap='jet', alpha=0.5)
plt.title('Class Activation Map')

plt.tight_layout()
plt.show()

# %%
def visualize_cam(model, img):
    # Extract the last convolutional layer
    last_conv_layer = model.get_layer('conv2d_2')
    
    # Define a new model that outputs the last conv layer and the model's predicted class probabilities
    cam_model = tf.keras.Model(model.input, (last_conv_layer.output, model.output))
    
    # Reshape the input image to match the expected input shape of the model
    img = np.reshape(img, (1, 64, 64, 1))
    
    # Calculate the gradients of the predicted class with respect to the output feature map of the last conv layer
    with tf.GradientTape() as tape:
        conv_outputs, predictions = cam_model(img)
        predicted_class = tf.argmax(predictions[0])
        gradient = tape.gradient(predictions[:, predicted_class], conv_outputs)
    
    # Compute the weights using global average pooling on the gradients
    weights = tf.reduce_mean(gradient[0], axis=(0, 1))
    
    # Get the feature map values and resize them to match the input image size
    feature_map = conv_outputs[0]
    cam = np.dot(feature_map, weights)
    cam = cv2.resize(cam, (img.shape[2], img.shape[1]))
    cam = np.maximum(cam, 0)
    cam = cam / np.max(cam)
    
    return cam

cam = visualize_cam(model, test_image)

# Plot the original image and the CAM
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.imshow(cam, cmap='jet', alpha=0.5)
plt.title('Class Activation Map')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Class Activation Maps (CAM) of First Layer

# %%
def visualize_cam(model, img):
    # Extract the last convolutional layer
    last_conv_layer = model.get_layer('conv2d_2')
    
    # Define a new model that outputs the last conv layer and the model's predicted class probabilities
    cam_model = tf.keras.Model(model.input, (last_conv_layer.output, model.output))
    
    # Reshape the input image to match the expected input shape of the model
    img = np.reshape(img, (-1, 64, 64, 1))
    
    # Calculate the gradients of the predicted class with respect to the output feature map of the last conv layer
    with tf.GradientTape() as tape:
        conv_outputs, predictions = cam_model(img)
        predicted_class = tf.argmax(predictions[0])
        gradient = tape.gradient(predictions[:, predicted_class], conv_outputs)
    
    # Compute the weights using global average pooling on the gradients
    weights = tf.reduce_mean(gradient[0], axis=(0, 1))
    
    # Get the feature map values and resize them to match the input image size
    feature_map = conv_outputs[0]
    cam = np.dot(feature_map, weights)
    cam = cv2.resize(cam, (img.shape[2], img.shape[1]))
    cam = np.maximum(cam, 0)
    cam = cam / np.max(cam)
    
    return cam



# Reshape the image to match the expected input shape of the model
test_image = np.reshape(test_image, (64, 64))
test_image = np.expand_dims(test_image, axis=-1)
test_image = np.expand_dims(test_image, axis=0)

cam = visualize_cam(model, test_image)

# Plot the original image and the CAM
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.imshow(cam, cmap='jet', alpha=0.5)
plt.title('Class Activation Map')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Class Activation Maps (CAM) of 2nd Layer:

# %%
def visualize_cam(model, img):
    # Extract the last convolutional layer
    last_conv_layer = model.get_layer('conv2d_3')
    
    # Define a new model that outputs the last conv layer and the model's predicted class probabilities
    cam_model = tf.keras.Model(model.input, (last_conv_layer.output, model.output))
    
    # Calculate the gradients of the predicted class with respect to the output feature map of the last conv layer
    with tf.GradientTape() as tape:
        conv_outputs, predictions = cam_model(img)
        predicted_class = tf.argmax(predictions[0])
        gradient = tape.gradient(predictions[:, predicted_class], conv_outputs)
    
    # Compute the weights using global average pooling on the gradients
    weights = tf.reduce_mean(gradient[0], axis=(0, 1))
    
    # Get the feature map values and resize them to match the input image size
    feature_map = conv_outputs[0]
    cam = np.dot(feature_map, weights)
    cam = cv2.resize(cam, (img.shape[2], img.shape[1]))
    cam = np.maximum(cam, 0)
    cam = cam / np.max(cam)
    
    return cam


# Choose an image from the test set
test_image = X_test[3]

# Reshape the image to match the input shape of the model
test_image = np.reshape(test_image, (1, 64, 64, 1))

# Generate the CAM for the chosen image
cam = visualize_cam(model, test_image)

# Plot the original image and the CAM
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(test_image[0, :, :, 0], cmap='gray')
plt.imshow(cam, cmap='jet', alpha=0.5)
plt.title('Class Activation Map')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Grad-CAM:

# %%
from tensorflow.keras.models import Model

# Select a sample image from your test set
sample_image = X_test[0]

# Create a model that maps the input image to the activations of the last conv layer as well as the output predictions
grad_model = Model([model.inputs], [model.get_layer('conv2d_3').output, model.output])

# Get the gradient of the top predicted class for our input image with respect to the activations of the last conv layer
with tf.GradientTape() as tape:
    last_conv_layer_output, preds = grad_model(np.expand_dims(sample_image, axis=0))
    pred_index = np.argmax(preds[0])
    class_channel = preds[:, pred_index]

# This is the gradient of the output neuron (top predicted or chosen)
# with regard to the output feature map of the last conv layer
grads = tape.gradient(class_channel, last_conv_layer_output)

# This is a vector where each entry is the mean intensity of the gradient over a specific feature map channel
pooled_grads = K.mean(grads, axis=(0, 1, 2))

# We multiply each channel in the feature map array by "how important this channel is"
# with regard to the top predicted class
last_conv_layer_output = last_conv_layer_output[0]
heatmap = last_conv_layer_output @ pooled_grads[..., np.newaxis]
heatmap = np.squeeze(heatmap)

# Normalize the heatmap between 0 & 1 for visualization
heatmap = np.maximum(heatmap, 0) / np.max(heatmap)

# Show the heatmap
plt.matshow(heatmap)
plt.show()

# %% [markdown]
# # Feature Maps:

# %%
def visualize_feature_maps(model, img):
    # Extract the intermediate feature maps
    layer_outputs = [layer.output for layer in model.layers if 'conv2d' in layer.name]
    activation_model = tf.keras.Model(inputs=model.input, outputs=layer_outputs)
    feature_maps = activation_model.predict(img)
    
    # Plot the feature maps
    for layer, feature_map in zip(model.layers, feature_maps):
        if 'conv2d' in layer.name:
            plt.figure(figsize=(8, 4))
            plt.imshow(feature_map[0, :, :, 0], cmap='gray')
            plt.title(layer.name + ' Feature Map')
            plt.show()

# Visualize the feature maps for the chosen image
visualize_feature_maps(model, test_image)
# Out:
# 1/1 [==============================] - 0s 54ms/step

# %% [markdown]
# # Filter Visualization:

# %%
# Get the weights of the first convolution layer
weights1 = model.layers[0].get_weights()[0]

# Normalize the weights to be between 0 and 1
weights1 = (weights1 - weights1.min())/(weights1.max()-weights1.min())

# Plot the weights as images
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(weights1[:,:,:,i], cmap='gray')
plt.show()

# %% [markdown]
# # Activation Histograms:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# Specify the layer you want to visualize
layer_name = 'conv2d_1'  # Change this to the layer name you're interested in
filter_index = 0  # Can be any integer from 0 to 511, as there are 512 filters in that layer

# Grab a reference to the input of the model and the specified layer
input_img = model.input
layer_output = layer_dict[layer_name].output

# Build a function that returns the activation values given the input picture
activation_func = K.function([input_img], [layer_output])

# Use the above function to compute the activations
activations = activation_func([X_test[0].reshape(1, 64, 64, 1)])

# Get histogram data
activation_values = activations[0].flatten()

# Create histogram
plt.figure(figsize=(10, 6))
sns.histplot(activation_values, bins=50, kde=True)
plt.title(f'Activation Histogram for Layer: {layer_name}')
plt.xlabel('Activation Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Learning Curves:

# %%
# Plotting the accuracy and loss
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Details on Image Files

# %%
# Specify the folder path containing the images
folder_path = "Img"

# Get a list of image file names in the folder
image_files = os.listdir(folder_path)

# Iterate over the image files
for file_name in image_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, file_name)

    # Open the image file
    image = Image.open(file_path)

    # Get the pixel size of the image
    width, height = image.size

    # Print the pixel size
    print(f"Image: {file_name}, Width: {width}px, Height: {height}px")
# Out:
# Image: img001-001.png, Width: 1200px, Height: 900px
# Image: img001-002.png, Width: 1200px, Height: 900px
# Image: img001-003.png, Width: 1200px, Height: 900px
# Image: img001-004.png, Width: 1200px, Height: 900px
# Image: img001-005.png, Width: 1200px, Height: 900px
# Image: img001-006.png, Width: 1200px, Height: 900px
# Image: img001-007.png, Width: 1200px, Height: 900px
# Image: img001-008.png, Width: 1200px, Height: 900px
# Image: img001-009.png, Width: 1200px, Height: 900px
# Image: img001-010.png, Width: 1200px, Height: 900px
# Image: img001-011.png, Width: 1200px, Height: 900px
# Image: img001-012.png, Width: 1200px, Height: 900px
# Image: img001-013.png, Width: 1200px, Height: 900px
# Image: img001-014.png, Width: 1200px, Height: 900px
# Image: img001-015.png, Width: 1200px, Height: 900px
# Image: img001-016.png, Width: 1200px, Height: 900px
# Image: img001-017.png, Width: 1200px, Height: 900px
# Image: img001-018.png, Width: 1200px, Height: 900px
# Image: img001-019.png, Width: 1200px, Height: 900px
# Image: img001-020.png, Width: 1200px, Height: 900px
# Image: img001-021.png, Width: 1200px, Height: 900px
# Image: img001-022.png, Width: 1200px, Height: 900px
# Image: img001-023.png, Width: 1200px, Height: 900px
# Image: img001-024.png, Width: 1200px, Height: 900px
# Image: img001-025.png, Width: 1200px, Height: 900px
# Image: img001-026.png, Width: 1200px, Height: 900px
# Image: img001-027.png, Width: 1200px, Height: 900px
# Image: img001-028.png, Width: 1200px, Height: 900px
# Image: img001-029.png, Width: 1200px, Height: 900px
# Image: img001-030.png, Width: 1200px, Height: 900px
# Image: img001-031.png, Width: 1200px, Height: 900px
# Image: img001-032.png, Width: 1200px, Height: 900px
# Image: img001-033.png, Width: 1200px, Height: 900px
# Image: img001-034.png, Width: 1200px, Height: 900px
# Image: img001-035.png, Width: 1200px, Height: 900px
# Image: img001-036.png, Width: 1200px, Height: 900px
# Image: img001-037.png, Width: 1200px, Height: 900px
# Image: img001-038.png, Width: 1200px, Height: 900px
# Image: img001-039.png, Width: 1200px, Height: 900px
# Image: img001-040.png, Width: 1200px, Height: 900px
# Image: img001-041.png, Width: 1200px, Height: 900px
# Image: img001-042.png, Width: 1200px, Height: 900px
# Image: img001-043.png, Width: 1200px, Height: 900px
# Image: img001-044.png, Width: 1200px, Height: 900px
# Image: img001-045.png, Width: 1200px, Height: 900px
# Image: img001-046.png, Width: 1200px, Height: 900px
# Image: img001-047.png, Width: 1200px, Height: 900px
# Image: img001-048.png, Width: 1200px, Height: 900px
# Image: img001-049.png, Width: 1200px, Height: 900px
# Image: img001-050.png, Width: 1200px, Height: 900px
# Image: img001-051.png, Width: 1200px, Height: 900px
# Image: img001-052.png, Width: 1200px, Height: 900px
# Image: img001-053.png, Width: 1200px, Height: 900px
# Image: img001-054.png, Width: 1200px, Height: 900px
# Image: img001-055.png, Width: 1200px, Height: 900px
# Image: img002-001.png, Width: 1200px, Height: 900px
# Image: img002-002.png, Width: 1200px, Height: 900px
# Image: img002-003.png, Width: 1200px, Height: 900px
# Image: img002-004.png, Width: 1200px, Height: 900px
# Image: img002-005.png, Width: 1200px, Height: 900px
# Image: img002-006.png, Width: 1200px, Height: 900px
# Image: img002-007.png, Width: 1200px, Height: 900px
# Image: img002-008.png, Width: 1200px, Height: 900px
# Image: img002-009.png, Width: 1200px, Height: 900px
# Image: img002-010.png, Width: 1200px, Height: 900px
# Image: img002-011.png, Width: 1200px, Height: 900px
# Image: img002-012.png, Width: 1200px, Height: 900px
# Image: img002-013.png, Width: 1200px, Height: 900px
# Image: img002-014.png, Width: 1200px, Height: 900px
# Image: img002-015.png, Width: 1200px, Height: 900px
# Image: img002-016.png, Width: 1200px, Height: 900px
# Image: img002-017.png, Width: 1200px, Height: 900px
# Image: img002-018.png, Width: 1200px, Height: 900px
# Image: img002-019.png, Width: 1200px, Height: 900px
# Image: img002-020.png, Width: 1200px, Height: 900px
# Image: img002-021.png, Width: 1200px, Height: 900px
# Image: img002-022.png, Width: 1200px, Height: 900px
# Image: img002-023.png, Width: 1200px, Height: 900px
# Image: img002-024.png, Width: 1200px, Height: 900px
# Image: img002-025.png, Width: 1200px, Height: 900px
# Image: img002-026.png, Width: 1200px, Height: 900px
# Image: img002-027.png, Width: 1200px, Height: 900px
# Image: img002-028.png, Width: 1200px, Height: 900px
# Image: img002-029.png, Width: 1200px, Height: 900px
# Image: img002-030.png, Width: 1200px, Height: 900px
# Image: img002-031.png, Width: 1200px, Height: 900px
# Image: img002-032.png, Width: 1200px, Height: 900px
# Image: img002-033.png, Width: 1200px, Height: 900px
# Image: img002-034.png, Width: 1200px, Height: 900px
# Image: img002-035.png, Width: 1200px, Height: 900px
# Image: img002-036.png, Width: 1200px, Height: 900px
# Image: img002-037.png, Width: 1200px, Height: 900px
# Image: img002-038.png, Width: 1200px, Height: 900px
# Image: img002-039.png, Width: 1200px, Height: 900px
# Image: img002-040.png, Width: 1200px, Height: 900px
# Image: img002-041.png, Width: 1200px, Height: 900px
# Image: img002-042.png, Width: 1200px, Height: 900px
# Image: img002-043.png, Width: 1200px, Height: 900px
# Image: img002-044.png, Width: 1200px, Height: 900px
# Image: img002-045.png, Width: 1200px, Height: 900px
# Image: img002-046.png, Width: 1200px, Height: 900px
# Image: img002-047.png, Width: 1200px, Height: 900px
# Image: img002-048.png, Width: 1200px, Height: 900px
# Image: img002-049.png, Width: 1200px, Height: 900px
# Image: img002-050.png, Width: 1200px, Height: 900px
# Image: img002-051.png, Width: 1200px, Height: 900px
# Image: img002-052.png, Width: 1200px, Height: 900px
# Image: img002-053.png, Width: 1200px, Height: 900px
# Image: img002-054.png, Width: 1200px, Height: 900px
# Image: img002-055.png, Width: 1200px, Height: 900px
# Image: img003-001.png, Width: 1200px, Height: 900px
# Image: img003-002.png, Width: 1200px, Height: 900px
# Image: img003-003.png, Width: 1200px, Height: 900px
# Image: img003-004.png, Width: 1200px, Height: 900px
# Image: img003-005.png, Width: 1200px, Height: 900px
# Image: img003-006.png, Width: 1200px, Height: 900px
# Image: img003-007.png, Width: 1200px, Height: 900px
# Image: img003-008.png, Width: 1200px, Height: 900px
# Image: img003-009.png, Width: 1200px, Height: 900px
# Image: img003-010.png, Width: 1200px, Height: 900px
# Image: img003-011.png, Width: 1200px, Height: 900px
# Image: img003-012.png, Width: 1200px, Height: 900px
# Image: img003-013.png, Width: 1200px, Height: 900px
# Image: img003-014.png, Width: 1200px, Height: 900px
# Image: img003-015.png, Width: 1200px, Height: 900px
# Image: img003-016.png, Width: 1200px, Height: 900px
# Image: img003-017.png, Width: 1200px, Height: 900px
# Image: img003-018.png, Width: 1200px, Height: 900px
# Image: img003-019.png, Width: 1200px, Height: 900px
# Image: img003-020.png, Width: 1200px, Height: 900px
# Image: img003-021.png, Width: 1200px, Height: 900px
# Image: img003-022.png, Width: 1200px, Height: 900px
# Image: img003-023.png, Width: 1200px, Height: 900px
# Image: img003-024.png, Width: 1200px, Height: 900px
# Image: img003-025.png, Width: 1200px, Height: 900px
# Image: img003-026.png, Width: 1200px, Height: 900px
# Image: img003-027.png, Width: 1200px, Height: 900px
# Image: img003-028.png, Width: 1200px, Height: 900px
# Image: img003-029.png, Width: 1200px, Height: 900px
# Image: img003-030.png, Width: 1200px, Height: 900px
# Image: img003-031.png, Width: 1200px, Height: 900px
# Image: img003-032.png, Width: 1200px, Height: 900px
# Image: img003-033.png, Width: 1200px, Height: 900px
# Image: img003-034.png, Width: 1200px, Height: 900px
# Image: img003-035.png, Width: 1200px, Height: 900px
# Image: img003-036.png, Width: 1200px, Height: 900px
# Image: img003-037.png, Width: 1200px, Height: 900px
# Image: img003-038.png, Width: 1200px, Height: 900px
# Image: img003-039.png, Width: 1200px, Height: 900px
# Image: img003-040.png, Width: 1200px, Height: 900px
# Image: img003-041.png, Width: 1200px, Height: 900px
# Image: img003-042.png, Width: 1200px, Height: 900px
# Image: img003-043.png, Width: 1200px, Height: 900px
# Image: img003-044.png, Width: 1200px, Height: 900px
# Image: img003-045.png, Width: 1200px, Height: 900px
# Image: img003-046.png, Width: 1200px, Height: 900px
# Image: img003-047.png, Width: 1200px, Height: 900px
# Image: img003-048.png, Width: 1200px, Height: 900px
# Image: img003-049.png, Width: 1200px, Height: 900px
# Image: img003-050.png, Width: 1200px, Height: 900px
# Image: img003-051.png, Width: 1200px, Height: 900px
# Image: img003-052.png, Width: 1200px, Height: 900px
# Image: img003-053.png, Width: 1200px, Height: 900px
# Image: img003-054.png, Width: 1200px, Height: 900px
# Image: img003-055.png, Width: 1200px, Height: 900px
# Image: img004-001.png, Width: 1200px, Height: 900px
# Image: img004-002.png, Width: 1200px, Height: 900px
# Image: img004-003.png, Width: 1200px, Height: 900px
# Image: img004-004.png, Width: 1200px, Height: 900px
# Image: img004-005.png, Width: 1200px, Height: 900px
# Image: img004-006.png, Width: 1200px, Height: 900px
# Image: img004-007.png, Width: 1200px, Height: 900px
# Image: img004-008.png, Width: 1200px, Height: 900px
# Image: img004-009.png, Width: 1200px, Height: 900px
# Image: img004-010.png, Width: 1200px, Height: 900px
# Image: img004-011.png, Width: 1200px, Height: 900px
# Image: img004-012.png, Width: 1200px, Height: 900px
# Image: img004-013.png, Width: 1200px, Height: 900px
# Image: img004-014.png, Width: 1200px, Height: 900px
# Image: img004-015.png, Width: 1200px, Height: 900px
# Image: img004-016.png, Width: 1200px, Height: 900px
# Image: img004-017.png, Width: 1200px, Height: 900px
# Image: img004-018.png, Width: 1200px, Height: 900px
# Image: img004-019.png, Width: 1200px, Height: 900px
# Image: img004-020.png, Width: 1200px, Height: 900px
# Image: img004-021.png, Width: 1200px, Height: 900px
# Image: img004-022.png, Width: 1200px, Height: 900px
# Image: img004-023.png, Width: 1200px, Height: 900px
# Image: img004-024.png, Width: 1200px, Height: 900px
# Image: img004-025.png, Width: 1200px, Height: 900px
# Image: img004-026.png, Width: 1200px, Height: 900px
# Image: img004-027.png, Width: 1200px, Height: 900px
# Image: img004-028.png, Width: 1200px, Height: 900px
# Image: img004-029.png, Width: 1200px, Height: 900px
# Image: img004-030.png, Width: 1200px, Height: 900px
# Image: img004-031.png, Width: 1200px, Height: 900px
# Image: img004-032.png, Width: 1200px, Height: 900px
# Image: img004-033.png, Width: 1200px, Height: 900px
# Image: img004-034.png, Width: 1200px, Height: 900px
# Image: img004-035.png, Width: 1200px, Height: 900px
# Image: img004-036.png, Width: 1200px, Height: 900px
# Image: img004-037.png, Width: 1200px, Height: 900px
# Image: img004-038.png, Width: 1200px, Height: 900px
# Image: img004-039.png, Width: 1200px, Height: 900px
# Image: img004-040.png, Width: 1200px, Height: 900px
# Image: img004-041.png, Width: 1200px, Height: 900px
# Image: img004-042.png, Width: 1200px, Height: 900px
# Image: img004-043.png, Width: 1200px, Height: 900px
# Image: img004-044.png, Width: 1200px, Height: 900px
# Image: img004-045.png, Width: 1200px, Height: 900px
# Image: img004-046.png, Width: 1200px, Height: 900px
# Image: img004-047.png, Width: 1200px, Height: 900px
# Image: img004-048.png, Width: 1200px, Height: 900px
# Image: img004-049.png, Width: 1200px, Height: 900px
# Image: img004-050.png, Width: 1200px, Height: 900px
# Image: img004-051.png, Width: 1200px, Height: 900px
# Image: img004-052.png, Width: 1200px, Height: 900px
# Image: img004-053.png, Width: 1200px, Height: 900px
# Image: img004-054.png, Width: 1200px, Height: 900px
# Image: img004-055.png, Width: 1200px, Height: 900px
# Image: img005-001.png, Width: 1200px, Height: 900px
# Image: img005-002.png, Width: 1200px, Height: 900px
# Image: img005-003.png, Width: 1200px, Height: 900px
# Image: img005-004.png, Width: 1200px, Height: 900px
# Image: img005-005.png, Width: 1200px, Height: 900px
# Image: img005-006.png, Width: 1200px, Height: 900px
# Image: img005-007.png, Width: 1200px, Height: 900px
# Image: img005-008.png, Width: 1200px, Height: 900px
# Image: img005-009.png, Width: 1200px, Height: 900px
# Image: img005-010.png, Width: 1200px, Height: 900px
# Image: img005-011.png, Width: 1200px, Height: 900px
# Image: img005-012.png, Width: 1200px, Height: 900px
# Image: img005-013.png, Width: 1200px, Height: 900px
# Image: img005-014.png, Width: 1200px, Height: 900px
# Image: img005-015.png, Width: 1200px, Height: 900px
# Image: img005-016.png, Width: 1200px, Height: 900px
# Image: img005-017.png, Width: 1200px, Height: 900px
# Image: img005-018.png, Width: 1200px, Height: 900px
# Image: img005-019.png, Width: 1200px, Height: 900px
# Image: img005-020.png, Width: 1200px, Height: 900px
# Image: img005-021.png, Width: 1200px, Height: 900px
# Image: img005-022.png, Width: 1200px, Height: 900px
# Image: img005-023.png, Width: 1200px, Height: 900px
# Image: img005-024.png, Width: 1200px, Height: 900px
# Image: img005-025.png, Width: 1200px, Height: 900px
# Image: img005-026.png, Width: 1200px, Height: 900px
# Image: img005-027.png, Width: 1200px, Height: 900px
# Image: img005-028.png, Width: 1200px, Height: 900px
# Image: img005-029.png, Width: 1200px, Height: 900px
# Image: img005-030.png, Width: 1200px, Height: 900px
# Image: img005-031.png, Width: 1200px, Height: 900px
# Image: img005-032.png, Width: 1200px, Height: 900px
# Image: img005-033.png, Width: 1200px, Height: 900px
# Image: img005-034.png, Width: 1200px, Height: 900px
# Image: img005-035.png, Width: 1200px, Height: 900px
# Image: img005-036.png, Width: 1200px, Height: 900px
# Image: img005-037.png, Width: 1200px, Height: 900px
# Image: img005-038.png, Width: 1200px, Height: 900px
# Image: img005-039.png, Width: 1200px, Height: 900px
# Image: img005-040.png, Width: 1200px, Height: 900px
# Image: img005-041.png, Width: 1200px, Height: 900px
# Image: img005-042.png, Width: 1200px, Height: 900px
# Image: img005-043.png, Width: 1200px, Height: 900px
# Image: img005-044.png, Width: 1200px, Height: 900px
# Image: img005-045.png, Width: 1200px, Height: 900px
# Image: img005-046.png, Width: 1200px, Height: 900px
# Image: img005-047.png, Width: 1200px, Height: 900px
# Image: img005-048.png, Width: 1200px, Height: 900px
# Image: img005-049.png, Width: 1200px, Height: 900px
# Image: img005-050.png, Width: 1200px, Height: 900px
# Image: img005-051.png, Width: 1200px, Height: 900px
# Image: img005-052.png, Width: 1200px, Height: 900px
# Image: img005-053.png, Width: 1200px, Height: 900px
# Image: img005-054.png, Width: 1200px, Height: 900px
# Image: img005-055.png, Width: 1200px, Height: 900px
# Image: img006-001.png, Width: 1200px, Height: 900px
# Image: img006-002.png, Width: 1200px, Height: 900px
# Image: img006-003.png, Width: 1200px, Height: 900px
# Image: img006-004.png, Width: 1200px, Height: 900px
# Image: img006-005.png, Width: 1200px, Height: 900px
# Image: img006-006.png, Width: 1200px, Height: 900px
# Image: img006-007.png, Width: 1200px, Height: 900px
# Image: img006-008.png, Width: 1200px, Height: 900px
# Image: img006-009.png, Width: 1200px, Height: 900px
# Image: img006-010.png, Width: 1200px, Height: 900px
# Image: img006-011.png, Width: 1200px, Height: 900px
# Image: img006-012.png, Width: 1200px, Height: 900px
# Image: img006-013.png, Width: 1200px, Height: 900px
# Image: img006-014.png, Width: 1200px, Height: 900px
# Image: img006-015.png, Width: 1200px, Height: 900px
# Image: img006-016.png, Width: 1200px, Height: 900px
# Image: img006-017.png, Width: 1200px, Height: 900px
# Image: img006-018.png, Width: 1200px, Height: 900px
# Image: img006-019.png, Width: 1200px, Height: 900px
# Image: img006-020.png, Width: 1200px, Height: 900px
# Image: img006-021.png, Width: 1200px, Height: 900px
# Image: img006-022.png, Width: 1200px, Height: 900px
# Image: img006-023.png, Width: 1200px, Height: 900px
# Image: img006-024.png, Width: 1200px, Height: 900px
# Image: img006-025.png, Width: 1200px, Height: 900px
# Image: img006-026.png, Width: 1200px, Height: 900px
# Image: img006-027.png, Width: 1200px, Height: 900px
# Image: img006-028.png, Width: 1200px, Height: 900px
# Image: img006-029.png, Width: 1200px, Height: 900px
# Image: img006-030.png, Width: 1200px, Height: 900px
# Image: img006-031.png, Width: 1200px, Height: 900px
# Image: img006-032.png, Width: 1200px, Height: 900px
# Image: img006-033.png, Width: 1200px, Height: 900px
# Image: img006-034.png, Width: 1200px, Height: 900px
# Image: img006-035.png, Width: 1200px, Height: 900px
# Image: img006-036.png, Width: 1200px, Height: 900px
# Image: img006-037.png, Width: 1200px, Height: 900px
# Image: img006-038.png, Width: 1200px, Height: 900px
# Image: img006-039.png, Width: 1200px, Height: 900px
# Image: img006-040.png, Width: 1200px, Height: 900px
# Image: img006-041.png, Width: 1200px, Height: 900px
# Image: img006-042.png, Width: 1200px, Height: 900px
# Image: img006-043.png, Width: 1200px, Height: 900px
# Image: img006-044.png, Width: 1200px, Height: 900px
# Image: img006-045.png, Width: 1200px, Height: 900px
# Image: img006-046.png, Width: 1200px, Height: 900px
# Image: img006-047.png, Width: 1200px, Height: 900px
# Image: img006-048.png, Width: 1200px, Height: 900px
# Image: img006-049.png, Width: 1200px, Height: 900px
# Image: img006-050.png, Width: 1200px, Height: 900px
# Image: img006-051.png, Width: 1200px, Height: 900px
# Image: img006-052.png, Width: 1200px, Height: 900px
# Image: img006-053.png, Width: 1200px, Height: 900px
# Image: img006-054.png, Width: 1200px, Height: 900px
# Image: img006-055.png, Width: 1200px, Height: 900px
# Image: img007-001.png, Width: 1200px, Height: 900px
# Image: img007-002.png, Width: 1200px, Height: 900px
# Image: img007-003.png, Width: 1200px, Height: 900px
# Image: img007-004.png, Width: 1200px, Height: 900px
# Image: img007-005.png, Width: 1200px, Height: 900px
# Image: img007-006.png, Width: 1200px, Height: 900px
# Image: img007-007.png, Width: 1200px, Height: 900px
# Image: img007-008.png, Width: 1200px, Height: 900px
# Image: img007-009.png, Width: 1200px, Height: 900px
# Image: img007-010.png, Width: 1200px, Height: 900px
# Image: img007-011.png, Width: 1200px, Height: 900px
# Image: img007-012.png, Width: 1200px, Height: 900px
# Image: img007-013.png, Width: 1200px, Height: 900px
# Image: img007-014.png, Width: 1200px, Height: 900px
# Image: img007-015.png, Width: 1200px, Height: 900px
# Image: img007-016.png, Width: 1200px, Height: 900px
# Image: img007-017.png, Width: 1200px, Height: 900px
# Image: img007-018.png, Width: 1200px, Height: 900px
# Image: img007-019.png, Width: 1200px, Height: 900px
# Image: img007-020.png, Width: 1200px, Height: 900px
# Image: img007-021.png, Width: 1200px, Height: 900px
# Image: img007-022.png, Width: 1200px, Height: 900px
# Image: img007-023.png, Width: 1200px, Height: 900px
# Image: img007-024.png, Width: 1200px, Height: 900px
# Image: img007-025.png, Width: 1200px, Height: 900px
# Image: img007-026.png, Width: 1200px, Height: 900px
# Image: img007-027.png, Width: 1200px, Height: 900px
# Image: img007-028.png, Width: 1200px, Height: 900px
# Image: img007-029.png, Width: 1200px, Height: 900px
# Image: img007-030.png, Width: 1200px, Height: 900px
# Image: img007-031.png, Width: 1200px, Height: 900px
# Image: img007-032.png, Width: 1200px, Height: 900px
# Image: img007-033.png, Width: 1200px, Height: 900px
# Image: img007-034.png, Width: 1200px, Height: 900px
# Image: img007-035.png, Width: 1200px, Height: 900px
# Image: img007-036.png, Width: 1200px, Height: 900px
# Image: img007-037.png, Width: 1200px, Height: 900px
# Image: img007-038.png, Width: 1200px, Height: 900px
# Image: img007-039.png, Width: 1200px, Height: 900px
# Image: img007-040.png, Width: 1200px, Height: 900px
# Image: img007-041.png, Width: 1200px, Height: 900px
# Image: img007-042.png, Width: 1200px, Height: 900px
# Image: img007-043.png, Width: 1200px, Height: 900px
# Image: img007-044.png, Width: 1200px, Height: 900px
# Image: img007-045.png, Width: 1200px, Height: 900px
# Image: img007-046.png, Width: 1200px, Height: 900px
# Image: img007-047.png, Width: 1200px, Height: 900px
# Image: img007-048.png, Width: 1200px, Height: 900px
# Image: img007-049.png, Width: 1200px, Height: 900px
# Image: img007-050.png, Width: 1200px, Height: 900px
# Image: img007-051.png, Width: 1200px, Height: 900px
# Image: img007-052.png, Width: 1200px, Height: 900px
# Image: img007-053.png, Width: 1200px, Height: 900px
# Image: img007-054.png, Width: 1200px, Height: 900px
# Image: img007-055.png, Width: 1200px, Height: 900px
# Image: img008-001.png, Width: 1200px, Height: 900px
# Image: img008-002.png, Width: 1200px, Height: 900px
# Image: img008-003.png, Width: 1200px, Height: 900px
# Image: img008-004.png, Width: 1200px, Height: 900px
# Image: img008-005.png, Width: 1200px, Height: 900px
# Image: img008-006.png, Width: 1200px, Height: 900px
# Image: img008-007.png, Width: 1200px, Height: 900px
# Image: img008-008.png, Width: 1200px, Height: 900px
# Image: img008-009.png, Width: 1200px, Height: 900px
# Image: img008-010.png, Width: 1200px, Height: 900px
# Image: img008-011.png, Width: 1200px, Height: 900px
# Image: img008-012.png, Width: 1200px, Height: 900px
# Image: img008-013.png, Width: 1200px, Height: 900px
# Image: img008-014.png, Width: 1200px, Height: 900px
# Image: img008-015.png, Width: 1200px, Height: 900px
# Image: img008-016.png, Width: 1200px, Height: 900px
# Image: img008-017.png, Width: 1200px, Height: 900px
# Image: img008-018.png, Width: 1200px, Height: 900px
# Image: img008-019.png, Width: 1200px, Height: 900px
# Image: img008-020.png, Width: 1200px, Height: 900px
# Image: img008-021.png, Width: 1200px, Height: 900px
# Image: img008-022.png, Width: 1200px, Height: 900px
# Image: img008-023.png, Width: 1200px, Height: 900px
# Image: img008-024.png, Width: 1200px, Height: 900px
# Image: img008-025.png, Width: 1200px, Height: 900px
# Image: img008-026.png, Width: 1200px, Height: 900px
# Image: img008-027.png, Width: 1200px, Height: 900px
# Image: img008-028.png, Width: 1200px, Height: 900px
# Image: img008-029.png, Width: 1200px, Height: 900px
# Image: img008-030.png, Width: 1200px, Height: 900px
# Image: img008-031.png, Width: 1200px, Height: 900px
# Image: img008-032.png, Width: 1200px, Height: 900px
# Image: img008-033.png, Width: 1200px, Height: 900px
# Image: img008-034.png, Width: 1200px, Height: 900px
# Image: img008-035.png, Width: 1200px, Height: 900px
# Image: img008-036.png, Width: 1200px, Height: 900px
# Image: img008-037.png, Width: 1200px, Height: 900px
# Image: img008-038.png, Width: 1200px, Height: 900px
# Image: img008-039.png, Width: 1200px, Height: 900px
# Image: img008-040.png, Width: 1200px, Height: 900px
# Image: img008-041.png, Width: 1200px, Height: 900px
# Image: img008-042.png, Width: 1200px, Height: 900px
# Image: img008-043.png, Width: 1200px, Height: 900px
# Image: img008-044.png, Width: 1200px, Height: 900px
# Image: img008-045.png, Width: 1200px, Height: 900px
# Image: img008-046.png, Width: 1200px, Height: 900px
# Image: img008-047.png, Width: 1200px, Height: 900px
# Image: img008-048.png, Width: 1200px, Height: 900px
# Image: img008-049.png, Width: 1200px, Height: 900px
# Image: img008-050.png, Width: 1200px, Height: 900px
# Image: img008-051.png, Width: 1200px, Height: 900px
# Image: img008-052.png, Width: 1200px, Height: 900px
# Image: img008-053.png, Width: 1200px, Height: 900px
# Image: img008-054.png, Width: 1200px, Height: 900px
# Image: img008-055.png, Width: 1200px, Height: 900px
# Image: img009-001.png, Width: 1200px, Height: 900px
# Image: img009-002.png, Width: 1200px, Height: 900px
# Image: img009-003.png, Width: 1200px, Height: 900px
# Image: img009-004.png, Width: 1200px, Height: 900px
# Image: img009-005.png, Width: 1200px, Height: 900px
# Image: img009-006.png, Width: 1200px, Height: 900px
# Image: img009-007.png, Width: 1200px, Height: 900px
# Image: img009-008.png, Width: 1200px, Height: 900px
# Image: img009-009.png, Width: 1200px, Height: 900px
# Image: img009-010.png, Width: 1200px, Height: 900px
# Image: img009-011.png, Width: 1200px, Height: 900px
# Image: img009-012.png, Width: 1200px, Height: 900px
# Image: img009-013.png, Width: 1200px, Height: 900px
# Image: img009-014.png, Width: 1200px, Height: 900px
# Image: img009-015.png, Width: 1200px, Height: 900px
# Image: img009-016.png, Width: 1200px, Height: 900px
# Image: img009-017.png, Width: 1200px, Height: 900px
# Image: img009-018.png, Width: 1200px, Height: 900px
# Image: img009-019.png, Width: 1200px, Height: 900px
# Image: img009-020.png, Width: 1200px, Height: 900px
# Image: img009-021.png, Width: 1200px, Height: 900px
# Image: img009-022.png, Width: 1200px, Height: 900px
# Image: img009-023.png, Width: 1200px, Height: 900px
# Image: img009-024.png, Width: 1200px, Height: 900px
# Image: img009-025.png, Width: 1200px, Height: 900px
# Image: img009-026.png, Width: 1200px, Height: 900px
# Image: img009-027.png, Width: 1200px, Height: 900px
# Image: img009-028.png, Width: 1200px, Height: 900px
# Image: img009-029.png, Width: 1200px, Height: 900px
# Image: img009-030.png, Width: 1200px, Height: 900px
# Image: img009-031.png, Width: 1200px, Height: 900px
# Image: img009-032.png, Width: 1200px, Height: 900px
# Image: img009-033.png, Width: 1200px, Height: 900px
# Image: img009-034.png, Width: 1200px, Height: 900px
# Image: img009-035.png, Width: 1200px, Height: 900px
# Image: img009-036.png, Width: 1200px, Height: 900px
# Image: img009-037.png, Width: 1200px, Height: 900px
# Image: img009-038.png, Width: 1200px, Height: 900px
# Image: img009-039.png, Width: 1200px, Height: 900px
# Image: img009-040.png, Width: 1200px, Height: 900px
# Image: img009-041.png, Width: 1200px, Height: 900px
# Image: img009-042.png, Width: 1200px, Height: 900px
# Image: img009-043.png, Width: 1200px, Height: 900px
# Image: img009-044.png, Width: 1200px, Height: 900px
# Image: img009-045.png, Width: 1200px, Height: 900px
# Image: img009-046.png, Width: 1200px, Height: 900px
# Image: img009-047.png, Width: 1200px, Height: 900px
# Image: img009-048.png, Width: 1200px, Height: 900px
# Image: img009-049.png, Width: 1200px, Height: 900px
# Image: img009-050.png, Width: 1200px, Height: 900px
# Image: img009-051.png, Width: 1200px, Height: 900px
# Image: img009-052.png, Width: 1200px, Height: 900px
# Image: img009-053.png, Width: 1200px, Height: 900px
# Image: img009-054.png, Width: 1200px, Height: 900px
# Image: img009-055.png, Width: 1200px, Height: 900px
# Image: img010-001.png, Width: 1200px, Height: 900px
# Image: img010-002.png, Width: 1200px, Height: 900px
# Image: img010-003.png, Width: 1200px, Height: 900px
# Image: img010-004.png, Width: 1200px, Height: 900px
# Image: img010-005.png, Width: 1200px, Height: 900px
# Image: img010-006.png, Width: 1200px, Height: 900px
# Image: img010-007.png, Width: 1200px, Height: 900px
# Image: img010-008.png, Width: 1200px, Height: 900px
# Image: img010-009.png, Width: 1200px, Height: 900px
# Image: img010-010.png, Width: 1200px, Height: 900px
# Image: img010-011.png, Width: 1200px, Height: 900px
# Image: img010-012.png, Width: 1200px, Height: 900px
# Image: img010-013.png, Width: 1200px, Height: 900px
# Image: img010-014.png, Width: 1200px, Height: 900px
# Image: img010-015.png, Width: 1200px, Height: 900px
# Image: img010-016.png, Width: 1200px, Height: 900px
# Image: img010-017.png, Width: 1200px, Height: 900px
# Image: img010-018.png, Width: 1200px, Height: 900px
# Image: img010-019.png, Width: 1200px, Height: 900px
# Image: img010-020.png, Width: 1200px, Height: 900px
# Image: img010-021.png, Width: 1200px, Height: 900px
# Image: img010-022.png, Width: 1200px, Height: 900px
# Image: img010-023.png, Width: 1200px, Height: 900px
# Image: img010-024.png, Width: 1200px, Height: 900px
# Image: img010-025.png, Width: 1200px, Height: 900px
# Image: img010-026.png, Width: 1200px, Height: 900px
# Image: img010-027.png, Width: 1200px, Height: 900px
# Image: img010-028.png, Width: 1200px, Height: 900px
# Image: img010-029.png, Width: 1200px, Height: 900px
# Image: img010-030.png, Width: 1200px, Height: 900px
# Image: img010-031.png, Width: 1200px, Height: 900px
# Image: img010-032.png, Width: 1200px, Height: 900px
# Image: img010-033.png, Width: 1200px, Height: 900px
# Image: img010-034.png, Width: 1200px, Height: 900px
# Image: img010-035.png, Width: 1200px, Height: 900px
# Image: img010-036.png, Width: 1200px, Height: 900px
# Image: img010-037.png, Width: 1200px, Height: 900px
# Image: img010-038.png, Width: 1200px, Height: 900px
# Image: img010-039.png, Width: 1200px, Height: 900px
# Image: img010-040.png, Width: 1200px, Height: 900px
# Image: img010-041.png, Width: 1200px, Height: 900px
# Image: img010-042.png, Width: 1200px, Height: 900px
# Image: img010-043.png, Width: 1200px, Height: 900px
# Image: img010-044.png, Width: 1200px, Height: 900px
# Image: img010-045.png, Width: 1200px, Height: 900px
# Image: img010-046.png, Width: 1200px, Height: 900px
# Image: img010-047.png, Width: 1200px, Height: 900px
# Image: img010-048.png, Width: 1200px, Height: 900px
# Image: img010-049.png, Width: 1200px, Height: 900px
# Image: img010-050.png, Width: 1200px, Height: 900px
# Image: img010-051.png, Width: 1200px, Height: 900px
# Image: img010-052.png, Width: 1200px, Height: 900px
# Image: img010-053.png, Width: 1200px, Height: 900px
# Image: img010-054.png, Width: 1200px, Height: 900px
# Image: img010-055.png, Width: 1200px, Height: 900px
# Image: img011-001.png, Width: 1200px, Height: 900px
# Image: img011-002.png, Width: 1200px, Height: 900px
# Image: img011-003.png, Width: 1200px, Height: 900px
# Image: img011-004.png, Width: 1200px, Height: 900px
# Image: img011-005.png, Width: 1200px, Height: 900px
# Image: img011-006.png, Width: 1200px, Height: 900px
# Image: img011-007.png, Width: 1200px, Height: 900px
# Image: img011-008.png, Width: 1200px, Height: 900px
# Image: img011-009.png, Width: 1200px, Height: 900px
# Image: img011-010.png, Width: 1200px, Height: 900px
# Image: img011-011.png, Width: 1200px, Height: 900px
# Image: img011-012.png, Width: 1200px, Height: 900px
# Image: img011-013.png, Width: 1200px, Height: 900px
# Image: img011-014.png, Width: 1200px, Height: 900px
# Image: img011-015.png, Width: 1200px, Height: 900px
# Image: img011-016.png, Width: 1200px, Height: 900px
# Image: img011-017.png, Width: 1200px, Height: 900px
# Image: img011-018.png, Width: 1200px, Height: 900px
# Image: img011-019.png, Width: 1200px, Height: 900px
# Image: img011-020.png, Width: 1200px, Height: 900px
# Image: img011-021.png, Width: 1200px, Height: 900px
# Image: img011-022.png, Width: 1200px, Height: 900px
# Image: img011-023.png, Width: 1200px, Height: 900px
# Image: img011-024.png, Width: 1200px, Height: 900px
# Image: img011-025.png, Width: 1200px, Height: 900px
# Image: img011-026.png, Width: 1200px, Height: 900px
# Image: img011-027.png, Width: 1200px, Height: 900px
# Image: img011-028.png, Width: 1200px, Height: 900px
# Image: img011-029.png, Width: 1200px, Height: 900px
# Image: img011-030.png, Width: 1200px, Height: 900px
# Image: img011-031.png, Width: 1200px, Height: 900px
# Image: img011-032.png, Width: 1200px, Height: 900px
# Image: img011-033.png, Width: 1200px, Height: 900px
# Image: img011-034.png, Width: 1200px, Height: 900px
# Image: img011-035.png, Width: 1200px, Height: 900px
# Image: img011-036.png, Width: 1200px, Height: 900px
# Image: img011-037.png, Width: 1200px, Height: 900px
# Image: img011-038.png, Width: 1200px, Height: 900px
# Image: img011-039.png, Width: 1200px, Height: 900px
# Image: img011-040.png, Width: 1200px, Height: 900px
# Image: img011-041.png, Width: 1200px, Height: 900px
# Image: img011-042.png, Width: 1200px, Height: 900px
# Image: img011-043.png, Width: 1200px, Height: 900px
# Image: img011-044.png, Width: 1200px, Height: 900px
# Image: img011-045.png, Width: 1200px, Height: 900px
# Image: img011-046.png, Width: 1200px, Height: 900px
# Image: img011-047.png, Width: 1200px, Height: 900px
# Image: img011-048.png, Width: 1200px, Height: 900px
# Image: img011-049.png, Width: 1200px, Height: 900px
# Image: img011-050.png, Width: 1200px, Height: 900px
# Image: img011-051.png, Width: 1200px, Height: 900px
# Image: img011-052.png, Width: 1200px, Height: 900px
# Image: img011-053.png, Width: 1200px, Height: 900px
# Image: img011-054.png, Width: 1200px, Height: 900px
# Image: img011-055.png, Width: 1200px, Height: 900px
# Image: img012-001.png, Width: 1200px, Height: 900px
# Image: img012-002.png, Width: 1200px, Height: 900px
# Image: img012-003.png, Width: 1200px, Height: 900px
# Image: img012-004.png, Width: 1200px, Height: 900px
# Image: img012-005.png, Width: 1200px, Height: 900px
# Image: img012-006.png, Width: 1200px, Height: 900px
# Image: img012-007.png, Width: 1200px, Height: 900px
# Image: img012-008.png, Width: 1200px, Height: 900px
# Image: img012-009.png, Width: 1200px, Height: 900px
# Image: img012-010.png, Width: 1200px, Height: 900px
# Image: img012-011.png, Width: 1200px, Height: 900px
# Image: img012-012.png, Width: 1200px, Height: 900px
# Image: img012-013.png, Width: 1200px, Height: 900px
# Image: img012-014.png, Width: 1200px, Height: 900px
# Image: img012-015.png, Width: 1200px, Height: 900px
# Image: img012-016.png, Width: 1200px, Height: 900px
# Image: img012-017.png, Width: 1200px, Height: 900px
# Image: img012-018.png, Width: 1200px, Height: 900px
# Image: img012-019.png, Width: 1200px, Height: 900px
# Image: img012-020.png, Width: 1200px, Height: 900px
# Image: img012-021.png, Width: 1200px, Height: 900px
# Image: img012-022.png, Width: 1200px, Height: 900px
# Image: img012-023.png, Width: 1200px, Height: 900px
# Image: img012-024.png, Width: 1200px, Height: 900px
# Image: img012-025.png, Width: 1200px, Height: 900px
# Image: img012-026.png, Width: 1200px, Height: 900px
# Image: img012-027.png, Width: 1200px, Height: 900px
# Image: img012-028.png, Width: 1200px, Height: 900px
# Image: img012-029.png, Width: 1200px, Height: 900px
# Image: img012-030.png, Width: 1200px, Height: 900px
# Image: img012-031.png, Width: 1200px, Height: 900px
# Image: img012-032.png, Width: 1200px, Height: 900px
# Image: img012-033.png, Width: 1200px, Height: 900px
# Image: img012-034.png, Width: 1200px, Height: 900px
# Image: img012-035.png, Width: 1200px, Height: 900px
# Image: img012-036.png, Width: 1200px, Height: 900px
# Image: img012-037.png, Width: 1200px, Height: 900px
# Image: img012-038.png, Width: 1200px, Height: 900px
# Image: img012-039.png, Width: 1200px, Height: 900px
# Image: img012-040.png, Width: 1200px, Height: 900px
# Image: img012-041.png, Width: 1200px, Height: 900px
# Image: img012-042.png, Width: 1200px, Height: 900px
# Image: img012-043.png, Width: 1200px, Height: 900px
# Image: img012-044.png, Width: 1200px, Height: 900px
# Image: img012-045.png, Width: 1200px, Height: 900px
# Image: img012-046.png, Width: 1200px, Height: 900px
# Image: img012-047.png, Width: 1200px, Height: 900px
# Image: img012-048.png, Width: 1200px, Height: 900px
# Image: img012-049.png, Width: 1200px, Height: 900px
# Image: img012-050.png, Width: 1200px, Height: 900px
# Image: img012-051.png, Width: 1200px, Height: 900px
# Image: img012-052.png, Width: 1200px, Height: 900px
# Image: img012-053.png, Width: 1200px, Height: 900px
# Image: img012-054.png, Width: 1200px, Height: 900px
# Image: img012-055.png, Width: 1200px, Height: 900px
# Image: img013-001.png, Width: 1200px, Height: 900px
# Image: img013-002.png, Width: 1200px, Height: 900px
# Image: img013-003.png, Width: 1200px, Height: 900px
# Image: img013-004.png, Width: 1200px, Height: 900px
# Image: img013-005.png, Width: 1200px, Height: 900px
# Image: img013-006.png, Width: 1200px, Height: 900px
# Image: img013-007.png, Width: 1200px, Height: 900px
# Image: img013-008.png, Width: 1200px, Height: 900px
# Image: img013-009.png, Width: 1200px, Height: 900px
# Image: img013-010.png, Width: 1200px, Height: 900px
# Image: img013-011.png, Width: 1200px, Height: 900px
# Image: img013-012.png, Width: 1200px, Height: 900px
# Image: img013-013.png, Width: 1200px, Height: 900px
# Image: img013-014.png, Width: 1200px, Height: 900px
# Image: img013-015.png, Width: 1200px, Height: 900px
# Image: img013-016.png, Width: 1200px, Height: 900px
# Image: img013-017.png, Width: 1200px, Height: 900px
# Image: img013-018.png, Width: 1200px, Height: 900px
# Image: img013-019.png, Width: 1200px, Height: 900px
# Image: img013-020.png, Width: 1200px, Height: 900px
# Image: img013-021.png, Width: 1200px, Height: 900px
# Image: img013-022.png, Width: 1200px, Height: 900px
# Image: img013-023.png, Width: 1200px, Height: 900px
# Image: img013-024.png, Width: 1200px, Height: 900px
# Image: img013-025.png, Width: 1200px, Height: 900px
# Image: img013-026.png, Width: 1200px, Height: 900px
# Image: img013-027.png, Width: 1200px, Height: 900px
# Image: img013-028.png, Width: 1200px, Height: 900px
# Image: img013-029.png, Width: 1200px, Height: 900px
# Image: img013-030.png, Width: 1200px, Height: 900px
# Image: img013-031.png, Width: 1200px, Height: 900px
# Image: img013-032.png, Width: 1200px, Height: 900px
# Image: img013-033.png, Width: 1200px, Height: 900px
# Image: img013-034.png, Width: 1200px, Height: 900px
# Image: img013-035.png, Width: 1200px, Height: 900px
# Image: img013-036.png, Width: 1200px, Height: 900px
# Image: img013-037.png, Width: 1200px, Height: 900px
# Image: img013-038.png, Width: 1200px, Height: 900px
# Image: img013-039.png, Width: 1200px, Height: 900px
# Image: img013-040.png, Width: 1200px, Height: 900px
# Image: img013-041.png, Width: 1200px, Height: 900px
# Image: img013-042.png, Width: 1200px, Height: 900px
# Image: img013-043.png, Width: 1200px, Height: 900px
# Image: img013-044.png, Width: 1200px, Height: 900px
# Image: img013-045.png, Width: 1200px, Height: 900px
# Image: img013-046.png, Width: 1200px, Height: 900px
# Image: img013-047.png, Width: 1200px, Height: 900px
# Image: img013-048.png, Width: 1200px, Height: 900px
# Image: img013-049.png, Width: 1200px, Height: 900px
# Image: img013-050.png, Width: 1200px, Height: 900px
# Image: img013-051.png, Width: 1200px, Height: 900px
# Image: img013-052.png, Width: 1200px, Height: 900px
# Image: img013-053.png, Width: 1200px, Height: 900px
# Image: img013-054.png, Width: 1200px, Height: 900px
# Image: img013-055.png, Width: 1200px, Height: 900px
# Image: img014-001.png, Width: 1200px, Height: 900px
# Image: img014-002.png, Width: 1200px, Height: 900px
# Image: img014-003.png, Width: 1200px, Height: 900px
# Image: img014-004.png, Width: 1200px, Height: 900px
# Image: img014-005.png, Width: 1200px, Height: 900px
# Image: img014-006.png, Width: 1200px, Height: 900px
# Image: img014-007.png, Width: 1200px, Height: 900px
# Image: img014-008.png, Width: 1200px, Height: 900px
# Image: img014-009.png, Width: 1200px, Height: 900px
# Image: img014-010.png, Width: 1200px, Height: 900px
# Image: img014-011.png, Width: 1200px, Height: 900px
# Image: img014-012.png, Width: 1200px, Height: 900px
# Image: img014-013.png, Width: 1200px, Height: 900px
# Image: img014-014.png, Width: 1200px, Height: 900px
# Image: img014-015.png, Width: 1200px, Height: 900px
# Image: img014-016.png, Width: 1200px, Height: 900px
# Image: img014-017.png, Width: 1200px, Height: 900px
# Image: img014-018.png, Width: 1200px, Height: 900px
# Image: img014-019.png, Width: 1200px, Height: 900px
# Image: img014-020.png, Width: 1200px, Height: 900px
# Image: img014-021.png, Width: 1200px, Height: 900px
# Image: img014-022.png, Width: 1200px, Height: 900px
# Image: img014-023.png, Width: 1200px, Height: 900px
# Image: img014-024.png, Width: 1200px, Height: 900px
# Image: img014-025.png, Width: 1200px, Height: 900px
# Image: img014-026.png, Width: 1200px, Height: 900px
# Image: img014-027.png, Width: 1200px, Height: 900px
# Image: img014-028.png, Width: 1200px, Height: 900px
# Image: img014-029.png, Width: 1200px, Height: 900px
# Image: img014-030.png, Width: 1200px, Height: 900px
# Image: img014-031.png, Width: 1200px, Height: 900px
# Image: img014-032.png, Width: 1200px, Height: 900px
# Image: img014-033.png, Width: 1200px, Height: 900px
# Image: img014-034.png, Width: 1200px, Height: 900px
# Image: img014-035.png, Width: 1200px, Height: 900px
# Image: img014-036.png, Width: 1200px, Height: 900px
# Image: img014-037.png, Width: 1200px, Height: 900px
# Image: img014-038.png, Width: 1200px, Height: 900px
# Image: img014-039.png, Width: 1200px, Height: 900px
# Image: img014-040.png, Width: 1200px, Height: 900px
# Image: img014-041.png, Width: 1200px, Height: 900px
# Image: img014-042.png, Width: 1200px, Height: 900px
# Image: img014-043.png, Width: 1200px, Height: 900px
# Image: img014-044.png, Width: 1200px, Height: 900px
# Image: img014-045.png, Width: 1200px, Height: 900px
# Image: img014-046.png, Width: 1200px, Height: 900px
# Image: img014-047.png, Width: 1200px, Height: 900px
# Image: img014-048.png, Width: 1200px, Height: 900px
# Image: img014-049.png, Width: 1200px, Height: 900px
# Image: img014-050.png, Width: 1200px, Height: 900px
# Image: img014-051.png, Width: 1200px, Height: 900px
# Image: img014-052.png, Width: 1200px, Height: 900px
# Image: img014-053.png, Width: 1200px, Height: 900px
# Image: img014-054.png, Width: 1200px, Height: 900px
# Image: img014-055.png, Width: 1200px, Height: 900px
# Image: img015-001.png, Width: 1200px, Height: 900px
# Image: img015-002.png, Width: 1200px, Height: 900px
# Image: img015-003.png, Width: 1200px, Height: 900px
# Image: img015-004.png, Width: 1200px, Height: 900px
# Image: img015-005.png, Width: 1200px, Height: 900px
# Image: img015-006.png, Width: 1200px, Height: 900px
# Image: img015-007.png, Width: 1200px, Height: 900px
# Image: img015-008.png, Width: 1200px, Height: 900px
# Image: img015-009.png, Width: 1200px, Height: 900px
# Image: img015-010.png, Width: 1200px, Height: 900px
# Image: img015-011.png, Width: 1200px, Height: 900px
# Image: img015-012.png, Width: 1200px, Height: 900px
# Image: img015-013.png, Width: 1200px, Height: 900px
# Image: img015-014.png, Width: 1200px, Height: 900px
# Image: img015-015.png, Width: 1200px, Height: 900px
# Image: img015-016.png, Width: 1200px, Height: 900px
# Image: img015-017.png, Width: 1200px, Height: 900px
# Image: img015-018.png, Width: 1200px, Height: 900px
# Image: img015-019.png, Width: 1200px, Height: 900px
# Image: img015-020.png, Width: 1200px, Height: 900px
# Image: img015-021.png, Width: 1200px, Height: 900px
# Image: img015-022.png, Width: 1200px, Height: 900px
# Image: img015-023.png, Width: 1200px, Height: 900px
# Image: img015-024.png, Width: 1200px, Height: 900px
# Image: img015-025.png, Width: 1200px, Height: 900px
# Image: img015-026.png, Width: 1200px, Height: 900px
# Image: img015-027.png, Width: 1200px, Height: 900px
# Image: img015-028.png, Width: 1200px, Height: 900px
# Image: img015-029.png, Width: 1200px, Height: 900px
# Image: img015-030.png, Width: 1200px, Height: 900px
# Image: img015-031.png, Width: 1200px, Height: 900px
# Image: img015-032.png, Width: 1200px, Height: 900px
# Image: img015-033.png, Width: 1200px, Height: 900px
# Image: img015-034.png, Width: 1200px, Height: 900px
# Image: img015-035.png, Width: 1200px, Height: 900px
# Image: img015-036.png, Width: 1200px, Height: 900px
# Image: img015-037.png, Width: 1200px, Height: 900px
# Image: img015-038.png, Width: 1200px, Height: 900px
# Image: img015-039.png, Width: 1200px, Height: 900px
# Image: img015-040.png, Width: 1200px, Height: 900px
# Image: img015-041.png, Width: 1200px, Height: 900px
# Image: img015-042.png, Width: 1200px, Height: 900px
# Image: img015-043.png, Width: 1200px, Height: 900px
# Image: img015-044.png, Width: 1200px, Height: 900px
# Image: img015-045.png, Width: 1200px, Height: 900px
# Image: img015-046.png, Width: 1200px, Height: 900px
# Image: img015-047.png, Width: 1200px, Height: 900px
# Image: img015-048.png, Width: 1200px, Height: 900px
# Image: img015-049.png, Width: 1200px, Height: 900px
# Image: img015-050.png, Width: 1200px, Height: 900px
# Image: img015-051.png, Width: 1200px, Height: 900px
# Image: img015-052.png, Width: 1200px, Height: 900px
# Image: img015-053.png, Width: 1200px, Height: 900px
# Image: img015-054.png, Width: 1200px, Height: 900px
# Image: img015-055.png, Width: 1200px, Height: 900px
# Image: img016-001.png, Width: 1200px, Height: 900px
# Image: img016-002.png, Width: 1200px, Height: 900px
# Image: img016-003.png, Width: 1200px, Height: 900px
# Image: img016-004.png, Width: 1200px, Height: 900px
# Image: img016-005.png, Width: 1200px, Height: 900px
# Image: img016-006.png, Width: 1200px, Height: 900px
# Image: img016-007.png, Width: 1200px, Height: 900px
# Image: img016-008.png, Width: 1200px, Height: 900px
# Image: img016-009.png, Width: 1200px, Height: 900px
# Image: img016-010.png, Width: 1200px, Height: 900px
# Image: img016-011.png, Width: 1200px, Height: 900px
# Image: img016-012.png, Width: 1200px, Height: 900px
# Image: img016-013.png, Width: 1200px, Height: 900px
# Image: img016-014.png, Width: 1200px, Height: 900px
# Image: img016-015.png, Width: 1200px, Height: 900px
# Image: img016-016.png, Width: 1200px, Height: 900px
# Image: img016-017.png, Width: 1200px, Height: 900px
# Image: img016-018.png, Width: 1200px, Height: 900px
# Image: img016-019.png, Width: 1200px, Height: 900px
# Image: img016-020.png, Width: 1200px, Height: 900px
# Image: img016-021.png, Width: 1200px, Height: 900px
# Image: img016-022.png, Width: 1200px, Height: 900px
# Image: img016-023.png, Width: 1200px, Height: 900px
# Image: img016-024.png, Width: 1200px, Height: 900px
# Image: img016-025.png, Width: 1200px, Height: 900px
# Image: img016-026.png, Width: 1200px, Height: 900px
# Image: img016-027.png, Width: 1200px, Height: 900px
# Image: img016-028.png, Width: 1200px, Height: 900px
# Image: img016-029.png, Width: 1200px, Height: 900px
# Image: img016-030.png, Width: 1200px, Height: 900px
# Image: img016-031.png, Width: 1200px, Height: 900px
# Image: img016-032.png, Width: 1200px, Height: 900px
# Image: img016-033.png, Width: 1200px, Height: 900px
# Image: img016-034.png, Width: 1200px, Height: 900px
# Image: img016-035.png, Width: 1200px, Height: 900px
# Image: img016-036.png, Width: 1200px, Height: 900px
# Image: img016-037.png, Width: 1200px, Height: 900px
# Image: img016-038.png, Width: 1200px, Height: 900px
# Image: img016-039.png, Width: 1200px, Height: 900px
# Image: img016-040.png, Width: 1200px, Height: 900px
# Image: img016-041.png, Width: 1200px, Height: 900px
# Image: img016-042.png, Width: 1200px, Height: 900px
# Image: img016-043.png, Width: 1200px, Height: 900px
# Image: img016-044.png, Width: 1200px, Height: 900px
# Image: img016-045.png, Width: 1200px, Height: 900px
# Image: img016-046.png, Width: 1200px, Height: 900px
# Image: img016-047.png, Width: 1200px, Height: 900px
# Image: img016-048.png, Width: 1200px, Height: 900px
# Image: img016-049.png, Width: 1200px, Height: 900px
# Image: img016-050.png, Width: 1200px, Height: 900px
# Image: img016-051.png, Width: 1200px, Height: 900px
# Image: img016-052.png, Width: 1200px, Height: 900px
# Image: img016-053.png, Width: 1200px, Height: 900px
# Image: img016-054.png, Width: 1200px, Height: 900px
# Image: img016-055.png, Width: 1200px, Height: 900px
# Image: img017-001.png, Width: 1200px, Height: 900px
# Image: img017-002.png, Width: 1200px, Height: 900px
# Image: img017-003.png, Width: 1200px, Height: 900px
# Image: img017-004.png, Width: 1200px, Height: 900px
# Image: img017-005.png, Width: 1200px, Height: 900px
# Image: img017-006.png, Width: 1200px, Height: 900px
# Image: img017-007.png, Width: 1200px, Height: 900px
# Image: img017-008.png, Width: 1200px, Height: 900px
# Image: img017-009.png, Width: 1200px, Height: 900px
# Image: img017-010.png, Width: 1200px, Height: 900px
# Image: img017-011.png, Width: 1200px, Height: 900px
# Image: img017-012.png, Width: 1200px, Height: 900px
# Image: img017-013.png, Width: 1200px, Height: 900px
# Image: img017-014.png, Width: 1200px, Height: 900px
# Image: img017-015.png, Width: 1200px, Height: 900px
# Image: img017-016.png, Width: 1200px, Height: 900px
# Image: img017-017.png, Width: 1200px, Height: 900px
# Image: img017-018.png, Width: 1200px, Height: 900px
# Image: img017-019.png, Width: 1200px, Height: 900px
# Image: img017-020.png, Width: 1200px, Height: 900px
# Image: img017-021.png, Width: 1200px, Height: 900px
# Image: img017-022.png, Width: 1200px, Height: 900px
# Image: img017-023.png, Width: 1200px, Height: 900px
# Image: img017-024.png, Width: 1200px, Height: 900px
# Image: img017-025.png, Width: 1200px, Height: 900px
# Image: img017-026.png, Width: 1200px, Height: 900px
# Image: img017-027.png, Width: 1200px, Height: 900px
# Image: img017-028.png, Width: 1200px, Height: 900px
# Image: img017-029.png, Width: 1200px, Height: 900px
# Image: img017-030.png, Width: 1200px, Height: 900px
# Image: img017-031.png, Width: 1200px, Height: 900px
# Image: img017-032.png, Width: 1200px, Height: 900px
# Image: img017-033.png, Width: 1200px, Height: 900px
# Image: img017-034.png, Width: 1200px, Height: 900px
# Image: img017-035.png, Width: 1200px, Height: 900px
# Image: img017-036.png, Width: 1200px, Height: 900px
# Image: img017-037.png, Width: 1200px, Height: 900px
# Image: img017-038.png, Width: 1200px, Height: 900px
# Image: img017-039.png, Width: 1200px, Height: 900px
# Image: img017-040.png, Width: 1200px, Height: 900px
# Image: img017-041.png, Width: 1200px, Height: 900px
# Image: img017-042.png, Width: 1200px, Height: 900px
# Image: img017-043.png, Width: 1200px, Height: 900px
# ...
# Image: img057-024.png, Width: 1200px, Height: 900px
# Image: img057-025.png, Width: 1200px, Height: 900px
# Image: img057-026.png, Width: 1200px, Height: 900px
# Image: img057-027.png, Width: 1200px, Height: 900px
# Image: img057-028.png, Width: 1200px, Height: 900px
# Image: img057-029.png, Width: 1200px, Height: 900px
# Image: img057-030.png, Width: 1200px, Height: 900px
# Image: img057-031.png, Width: 1200px, Height: 900px
# Image: img057-032.png, Width: 1200px, Height: 900px
# Image: img057-033.png, Width: 1200px, Height: 900px
# Image: img057-034.png, Width: 1200px, Height: 900px
# Image: img057-035.png, Width: 1200px, Height: 900px
# Image: img057-036.png, Width: 1200px, Height: 900px
# Image: img057-037.png, Width: 1200px, Height: 900px
# Image: img057-038.png, Width: 1200px, Height: 900px
# Image: img057-039.png, Width: 1200px, Height: 900px
# Image: img057-040.png, Width: 1200px, Height: 900px
# Image: img057-041.png, Width: 1200px, Height: 900px
# Image: img057-042.png, Width: 1200px, Height: 900px
# Image: img057-043.png, Width: 1200px, Height: 900px
# Image: img057-044.png, Width: 1200px, Height: 900px
# Image: img057-045.png, Width: 1200px, Height: 900px
# Image: img057-046.png, Width: 1200px, Height: 900px
# Image: img057-047.png, Width: 1200px, Height: 900px
# Image: img057-048.png, Width: 1200px, Height: 900px
# Image: img057-049.png, Width: 1200px, Height: 900px
# Image: img057-050.png, Width: 1200px, Height: 900px
# Image: img057-051.png, Width: 1200px, Height: 900px
# Image: img057-052.png, Width: 1200px, Height: 900px
# Image: img057-053.png, Width: 1200px, Height: 900px
# Image: img057-054.png, Width: 1200px, Height: 900px
# Image: img057-055.png, Width: 1200px, Height: 900px
# Image: img058-001.png, Width: 1200px, Height: 900px
# Image: img058-002.png, Width: 1200px, Height: 900px
# Image: img058-003.png, Width: 1200px, Height: 900px
# Image: img058-004.png, Width: 1200px, Height: 900px
# Image: img058-005.png, Width: 1200px, Height: 900px
# Image: img058-006.png, Width: 1200px, Height: 900px
# Image: img058-007.png, Width: 1200px, Height: 900px
# Image: img058-008.png, Width: 1200px, Height: 900px
# Image: img058-009.png, Width: 1200px, Height: 900px
# Image: img058-010.png, Width: 1200px, Height: 900px
# Image: img058-011.png, Width: 1200px, Height: 900px
# Image: img058-012.png, Width: 1200px, Height: 900px
# Image: img058-013.png, Width: 1200px, Height: 900px
# Image: img058-014.png, Width: 1200px, Height: 900px
# Image: img058-015.png, Width: 1200px, Height: 900px
# Image: img058-016.png, Width: 1200px, Height: 900px
# Image: img058-017.png, Width: 1200px, Height: 900px
# Image: img058-018.png, Width: 1200px, Height: 900px
# Image: img058-019.png, Width: 1200px, Height: 900px
# Image: img058-020.png, Width: 1200px, Height: 900px
# Image: img058-021.png, Width: 1200px, Height: 900px
# Image: img058-022.png, Width: 1200px, Height: 900px
# Image: img058-023.png, Width: 1200px, Height: 900px
# Image: img058-024.png, Width: 1200px, Height: 900px
# Image: img058-025.png, Width: 1200px, Height: 900px
# Image: img058-026.png, Width: 1200px, Height: 900px
# Image: img058-027.png, Width: 1200px, Height: 900px
# Image: img058-028.png, Width: 1200px, Height: 900px
# Image: img058-029.png, Width: 1200px, Height: 900px
# Image: img058-030.png, Width: 1200px, Height: 900px
# Image: img058-031.png, Width: 1200px, Height: 900px
# Image: img058-032.png, Width: 1200px, Height: 900px
# Image: img058-033.png, Width: 1200px, Height: 900px
# Image: img058-034.png, Width: 1200px, Height: 900px
# Image: img058-035.png, Width: 1200px, Height: 900px
# Image: img058-036.png, Width: 1200px, Height: 900px
# Image: img058-037.png, Width: 1200px, Height: 900px
# Image: img058-038.png, Width: 1200px, Height: 900px
# Image: img058-039.png, Width: 1200px, Height: 900px
# Image: img058-040.png, Width: 1200px, Height: 900px
# Image: img058-041.png, Width: 1200px, Height: 900px
# Image: img058-042.png, Width: 1200px, Height: 900px
# Image: img058-043.png, Width: 1200px, Height: 900px
# Image: img058-044.png, Width: 1200px, Height: 900px
# Image: img058-045.png, Width: 1200px, Height: 900px
# Image: img058-046.png, Width: 1200px, Height: 900px
# Image: img058-047.png, Width: 1200px, Height: 900px
# Image: img058-048.png, Width: 1200px, Height: 900px
# Image: img058-049.png, Width: 1200px, Height: 900px
# Image: img058-050.png, Width: 1200px, Height: 900px
# Image: img058-051.png, Width: 1200px, Height: 900px
# Image: img058-052.png, Width: 1200px, Height: 900px
# Image: img058-053.png, Width: 1200px, Height: 900px
# Image: img058-054.png, Width: 1200px, Height: 900px
# Image: img058-055.png, Width: 1200px, Height: 900px
# Image: img059-001.png, Width: 1200px, Height: 900px
# Image: img059-002.png, Width: 1200px, Height: 900px
# Image: img059-003.png, Width: 1200px, Height: 900px
# Image: img059-004.png, Width: 1200px, Height: 900px
# Image: img059-005.png, Width: 1200px, Height: 900px
# Image: img059-006.png, Width: 1200px, Height: 900px
# Image: img059-007.png, Width: 1200px, Height: 900px
# Image: img059-008.png, Width: 1200px, Height: 900px
# Image: img059-009.png, Width: 1200px, Height: 900px
# Image: img059-010.png, Width: 1200px, Height: 900px
# Image: img059-011.png, Width: 1200px, Height: 900px
# Image: img059-012.png, Width: 1200px, Height: 900px
# Image: img059-013.png, Width: 1200px, Height: 900px
# Image: img059-014.png, Width: 1200px, Height: 900px
# Image: img059-015.png, Width: 1200px, Height: 900px
# Image: img059-016.png, Width: 1200px, Height: 900px
# Image: img059-017.png, Width: 1200px, Height: 900px
# Image: img059-018.png, Width: 1200px, Height: 900px
# Image: img059-019.png, Width: 1200px, Height: 900px
# Image: img059-020.png, Width: 1200px, Height: 900px
# Image: img059-021.png, Width: 1200px, Height: 900px
# Image: img059-022.png, Width: 1200px, Height: 900px
# Image: img059-023.png, Width: 1200px, Height: 900px
# Image: img059-024.png, Width: 1200px, Height: 900px
# Image: img059-025.png, Width: 1200px, Height: 900px
# Image: img059-026.png, Width: 1200px, Height: 900px
# Image: img059-027.png, Width: 1200px, Height: 900px
# Image: img059-028.png, Width: 1200px, Height: 900px
# Image: img059-029.png, Width: 1200px, Height: 900px
# Image: img059-030.png, Width: 1200px, Height: 900px
# Image: img059-031.png, Width: 1200px, Height: 900px
# Image: img059-032.png, Width: 1200px, Height: 900px
# Image: img059-033.png, Width: 1200px, Height: 900px
# Image: img059-034.png, Width: 1200px, Height: 900px
# Image: img059-035.png, Width: 1200px, Height: 900px
# Image: img059-036.png, Width: 1200px, Height: 900px
# Image: img059-037.png, Width: 1200px, Height: 900px
# Image: img059-038.png, Width: 1200px, Height: 900px
# Image: img059-039.png, Width: 1200px, Height: 900px
# Image: img059-040.png, Width: 1200px, Height: 900px
# Image: img059-041.png, Width: 1200px, Height: 900px
# Image: img059-042.png, Width: 1200px, Height: 900px
# Image: img059-043.png, Width: 1200px, Height: 900px
# Image: img059-044.png, Width: 1200px, Height: 900px
# Image: img059-045.png, Width: 1200px, Height: 900px
# Image: img059-046.png, Width: 1200px, Height: 900px
# Image: img059-047.png, Width: 1200px, Height: 900px
# Image: img059-048.png, Width: 1200px, Height: 900px
# Image: img059-049.png, Width: 1200px, Height: 900px
# Image: img059-050.png, Width: 1200px, Height: 900px
# Image: img059-051.png, Width: 1200px, Height: 900px
# Image: img059-052.png, Width: 1200px, Height: 900px
# Image: img059-053.png, Width: 1200px, Height: 900px
# Image: img059-054.png, Width: 1200px, Height: 900px
# Image: img059-055.png, Width: 1200px, Height: 900px
# Image: img060-001.png, Width: 1200px, Height: 900px
# Image: img060-002.png, Width: 1200px, Height: 900px
# Image: img060-003.png, Width: 1200px, Height: 900px
# Image: img060-004.png, Width: 1200px, Height: 900px
# Image: img060-005.png, Width: 1200px, Height: 900px
# Image: img060-006.png, Width: 1200px, Height: 900px
# Image: img060-007.png, Width: 1200px, Height: 900px
# Image: img060-008.png, Width: 1200px, Height: 900px
# Image: img060-009.png, Width: 1200px, Height: 900px
# Image: img060-010.png, Width: 1200px, Height: 900px
# Image: img060-011.png, Width: 1200px, Height: 900px
# Image: img060-012.png, Width: 1200px, Height: 900px
# Image: img060-013.png, Width: 1200px, Height: 900px
# Image: img060-014.png, Width: 1200px, Height: 900px
# Image: img060-015.png, Width: 1200px, Height: 900px
# Image: img060-016.png, Width: 1200px, Height: 900px
# Image: img060-017.png, Width: 1200px, Height: 900px
# Image: img060-018.png, Width: 1200px, Height: 900px
# Image: img060-019.png, Width: 1200px, Height: 900px
# Image: img060-020.png, Width: 1200px, Height: 900px
# Image: img060-021.png, Width: 1200px, Height: 900px
# Image: img060-022.png, Width: 1200px, Height: 900px
# Image: img060-023.png, Width: 1200px, Height: 900px
# Image: img060-024.png, Width: 1200px, Height: 900px
# Image: img060-025.png, Width: 1200px, Height: 900px
# Image: img060-026.png, Width: 1200px, Height: 900px
# Image: img060-027.png, Width: 1200px, Height: 900px
# Image: img060-028.png, Width: 1200px, Height: 900px
# Image: img060-029.png, Width: 1200px, Height: 900px
# Image: img060-030.png, Width: 1200px, Height: 900px
# Image: img060-031.png, Width: 1200px, Height: 900px
# Image: img060-032.png, Width: 1200px, Height: 900px
# Image: img060-033.png, Width: 1200px, Height: 900px
# Image: img060-034.png, Width: 1200px, Height: 900px
# Image: img060-035.png, Width: 1200px, Height: 900px
# Image: img060-036.png, Width: 1200px, Height: 900px
# Image: img060-037.png, Width: 1200px, Height: 900px
# Image: img060-038.png, Width: 1200px, Height: 900px
# Image: img060-039.png, Width: 1200px, Height: 900px
# Image: img060-040.png, Width: 1200px, Height: 900px
# Image: img060-041.png, Width: 1200px, Height: 900px
# Image: img060-042.png, Width: 1200px, Height: 900px
# Image: img060-043.png, Width: 1200px, Height: 900px
# Image: img060-044.png, Width: 1200px, Height: 900px
# Image: img060-045.png, Width: 1200px, Height: 900px
# Image: img060-046.png, Width: 1200px, Height: 900px
# Image: img060-047.png, Width: 1200px, Height: 900px
# Image: img060-048.png, Width: 1200px, Height: 900px
# Image: img060-049.png, Width: 1200px, Height: 900px
# Image: img060-050.png, Width: 1200px, Height: 900px
# Image: img060-051.png, Width: 1200px, Height: 900px
# Image: img060-052.png, Width: 1200px, Height: 900px
# Image: img060-053.png, Width: 1200px, Height: 900px
# Image: img060-054.png, Width: 1200px, Height: 900px
# Image: img060-055.png, Width: 1200px, Height: 900px
# Image: img061-001.png, Width: 1200px, Height: 900px
# Image: img061-002.png, Width: 1200px, Height: 900px
# Image: img061-003.png, Width: 1200px, Height: 900px
# Image: img061-004.png, Width: 1200px, Height: 900px
# Image: img061-005.png, Width: 1200px, Height: 900px
# Image: img061-006.png, Width: 1200px, Height: 900px
# Image: img061-007.png, Width: 1200px, Height: 900px
# Image: img061-008.png, Width: 1200px, Height: 900px
# Image: img061-009.png, Width: 1200px, Height: 900px
# Image: img061-010.png, Width: 1200px, Height: 900px
# Image: img061-011.png, Width: 1200px, Height: 900px
# Image: img061-012.png, Width: 1200px, Height: 900px
# Image: img061-013.png, Width: 1200px, Height: 900px
# Image: img061-014.png, Width: 1200px, Height: 900px
# Image: img061-015.png, Width: 1200px, Height: 900px
# Image: img061-016.png, Width: 1200px, Height: 900px
# Image: img061-017.png, Width: 1200px, Height: 900px
# Image: img061-018.png, Width: 1200px, Height: 900px
# Image: img061-019.png, Width: 1200px, Height: 900px
# Image: img061-020.png, Width: 1200px, Height: 900px
# Image: img061-021.png, Width: 1200px, Height: 900px
# Image: img061-022.png, Width: 1200px, Height: 900px
# Image: img061-023.png, Width: 1200px, Height: 900px
# Image: img061-024.png, Width: 1200px, Height: 900px
# Image: img061-025.png, Width: 1200px, Height: 900px
# Image: img061-026.png, Width: 1200px, Height: 900px
# Image: img061-027.png, Width: 1200px, Height: 900px
# Image: img061-028.png, Width: 1200px, Height: 900px
# Image: img061-029.png, Width: 1200px, Height: 900px
# Image: img061-030.png, Width: 1200px, Height: 900px
# Image: img061-031.png, Width: 1200px, Height: 900px
# Image: img061-032.png, Width: 1200px, Height: 900px
# Image: img061-033.png, Width: 1200px, Height: 900px
# Image: img061-034.png, Width: 1200px, Height: 900px
# Image: img061-035.png, Width: 1200px, Height: 900px
# Image: img061-036.png, Width: 1200px, Height: 900px
# Image: img061-037.png, Width: 1200px, Height: 900px
# Image: img061-038.png, Width: 1200px, Height: 900px
# Image: img061-039.png, Width: 1200px, Height: 900px
# Image: img061-040.png, Width: 1200px, Height: 900px
# Image: img061-041.png, Width: 1200px, Height: 900px
# Image: img061-042.png, Width: 1200px, Height: 900px
# Image: img061-043.png, Width: 1200px, Height: 900px
# Image: img061-044.png, Width: 1200px, Height: 900px
# Image: img061-045.png, Width: 1200px, Height: 900px
# Image: img061-046.png, Width: 1200px, Height: 900px
# Image: img061-047.png, Width: 1200px, Height: 900px
# Image: img061-048.png, Width: 1200px, Height: 900px
# Image: img061-049.png, Width: 1200px, Height: 900px
# Image: img061-050.png, Width: 1200px, Height: 900px
# Image: img061-051.png, Width: 1200px, Height: 900px
# Image: img061-052.png, Width: 1200px, Height: 900px
# Image: img061-053.png, Width: 1200px, Height: 900px
# Image: img061-054.png, Width: 1200px, Height: 900px
# Image: img061-055.png, Width: 1200px, Height: 900px
# Image: img062-001.png, Width: 1200px, Height: 900px
# Image: img062-002.png, Width: 1200px, Height: 900px
# Image: img062-003.png, Width: 1200px, Height: 900px
# Image: img062-004.png, Width: 1200px, Height: 900px
# Image: img062-005.png, Width: 1200px, Height: 900px
# Image: img062-006.png, Width: 1200px, Height: 900px
# Image: img062-007.png, Width: 1200px, Height: 900px
# Image: img062-008.png, Width: 1200px, Height: 900px
# Image: img062-009.png, Width: 1200px, Height: 900px
# Image: img062-010.png, Width: 1200px, Height: 900px
# Image: img062-011.png, Width: 1200px, Height: 900px
# Image: img062-012.png, Width: 1200px, Height: 900px
# Image: img062-013.png, Width: 1200px, Height: 900px
# Image: img062-014.png, Width: 1200px, Height: 900px
# Image: img062-015.png, Width: 1200px, Height: 900px
# Image: img062-016.png, Width: 1200px, Height: 900px
# Image: img062-017.png, Width: 1200px, Height: 900px
# Image: img062-018.png, Width: 1200px, Height: 900px
# Image: img062-019.png, Width: 1200px, Height: 900px
# Image: img062-020.png, Width: 1200px, Height: 900px
# Image: img062-021.png, Width: 1200px, Height: 900px
# Image: img062-022.png, Width: 1200px, Height: 900px
# Image: img062-023.png, Width: 1200px, Height: 900px
# Image: img062-024.png, Width: 1200px, Height: 900px
# Image: img062-025.png, Width: 1200px, Height: 900px
# Image: img062-026.png, Width: 1200px, Height: 900px
# Image: img062-027.png, Width: 1200px, Height: 900px
# Image: img062-028.png, Width: 1200px, Height: 900px
# Image: img062-029.png, Width: 1200px, Height: 900px
# Image: img062-030.png, Width: 1200px, Height: 900px
# Image: img062-031.png, Width: 1200px, Height: 900px
# Image: img062-032.png, Width: 1200px, Height: 900px
# Image: img062-033.png, Width: 1200px, Height: 900px
# Image: img062-034.png, Width: 1200px, Height: 900px
# Image: img062-035.png, Width: 1200px, Height: 900px
# Image: img062-036.png, Width: 1200px, Height: 900px
# Image: img062-037.png, Width: 1200px, Height: 900px
# Image: img062-038.png, Width: 1200px, Height: 900px
# Image: img062-039.png, Width: 1200px, Height: 900px
# Image: img062-040.png, Width: 1200px, Height: 900px
# Image: img062-041.png, Width: 1200px, Height: 900px
# Image: img062-042.png, Width: 1200px, Height: 900px
# Image: img062-043.png, Width: 1200px, Height: 900px
# Image: img062-044.png, Width: 1200px, Height: 900px
# Image: img062-045.png, Width: 1200px, Height: 900px
# Image: img062-046.png, Width: 1200px, Height: 900px
# Image: img062-047.png, Width: 1200px, Height: 900px
# Image: img062-048.png, Width: 1200px, Height: 900px
# Image: img062-049.png, Width: 1200px, Height: 900px
# Image: img062-050.png, Width: 1200px, Height: 900px
# Image: img062-051.png, Width: 1200px, Height: 900px
# Image: img062-052.png, Width: 1200px, Height: 900px
# Image: img062-053.png, Width: 1200px, Height: 900px
# Image: img062-054.png, Width: 1200px, Height: 900px
# Image: img062-055.png, Width: 1200px, Height: 900px

# %%
#128 by (check proper size)


#Build out readme and PPT!!!!!!!!!!!!!



#Learn a deployment!!!!
